# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# download and unzip dataset
# !kaggle datasets download -d arnavr10880/concrete-crack-images-for-classification
# !unzip concrete-crack-images-for-classification.zip -d content
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: content/Positive/15001_1.jpg
#   inflating: content/Positive/15002_1.jpg
#   inflating: content/Positive/15003_1.jpg
#   inflating: content/Positive/15004_1.jpg
#   inflating: content/Positive/15005_1.jpg
#   inflating: content/Positive/15006_1.jpg
#   inflating: content/Positive/15007_1.jpg
#   inflating: content/Positive/15008_1.jpg
#   inflating: content/Positive/15009_1.jpg
#   inflating: content/Positive/15010_1.jpg
#   inflating: content/Positive/15011_1.jpg
#   inflating: content/Positive/15012_1.jpg
#   inflating: content/Positive/15013_1.jpg
#   inflating: content/Positive/15014_1.jpg
#   inflating: content/Positive/15015_1.jpg
#   inflating: content/Positive/15016_1.jpg
#   inflating: content/Positive/15017_1.jpg
#   inflating: content/Positive/15018_1.jpg
#   inflating: content/Positive/15019_1.jpg
#   inflating: content/Positive/15020_1.jpg
#   inflating: content/Positive/15021_1.jpg
#   inflating: content/Positive/15022_1.jpg
#   inflating: content/Positive/15023_1.jpg
#   inflating: content/Positive/15024_1.jpg
#   inflating: content/Positive/15025_1.jpg
#   inflating: content/Positive/15026_1.jpg
#   inflating: content/Positive/15027_1.jpg
#   inflating: content/Positive/15028_1.jpg
#   inflating: content/Positive/15029_1.jpg
#   inflating: content/Positive/15030_1.jpg
#   inflating: content/Positive/15031_1.jpg
#   inflating: content/Positive/15032_1.jpg
#   inflating: content/Positive/15033_1.jpg
#   inflating: content/Positive/15034_1.jpg
#   inflating: content/Positive/15035_1.jpg
#   inflating: content/Positive/15036_1.jpg
#   inflating: content/Positive/15037_1.jpg
#   inflating: content/Positive/15038_1.jpg
#   inflating: content/Positive/15039_1.jpg
#   inflating: content/Positive/15040_1.jpg
#   inflating: content/Positive/15041_1.jpg
#   inflating: content/Positive/15042_1.jpg
#   inflating: content/Positive/15043_1.jpg
#   inflating: content/Positive/15044_1.jpg
#   inflating: content/Positive/15045_1.jpg
#   inflating: content/Positive/15046_1.jpg
#   inflating: content/Positive/15047_1.jpg
#   inflating: content/Positive/15048_1.jpg
#   inflating: content/Positive/15049_1.jpg
#   inflating: content/Positive/15050_1.jpg
#   inflating: content/Positive/15051_1.jpg
#   inflating: content/Positive/15052_1.jpg
#   inflating: content/Positive/15053_1.jpg
#   inflating: content/Positive/15054_1.jpg
#   inflating: content/Positive/15055_1.jpg
#   inflating: content/Positive/15056_1.jpg
#   inflating: content/Positive/15057_1.jpg
#   inflating: content/Positive/15058_1.jpg
#   inflating: content/Positive/15059_1.jpg
#   inflating: content/Positive/15060_1.jpg
#   inflating: content/Positive/15061_1.jpg
#   inflating: content/Positive/15062_1.jpg
#   inflating: content/Positive/15063_1.jpg
#   inflating: content/Positive/15064_1.jpg
#   inflating: content/Positive/15065_1.jpg
#   inflating: content/Positive/15066_1.jpg
#   inflating: content/Positive/15067_1.jpg
#   inflating: content/Positive/15068_1.jpg
#   inflating: content/Positive/15069_1.jpg
#   inflating: content/Positive/15070_1.jpg
#   inflating: content/Positive/15071_1.jpg
#   inflating: content/Positive/15072_1.jpg
#   inflating: content/Positive/15073_1.jpg
#   inflating: content/Positive/15074_1.jpg
#   inflating: content/Positive/15075_1.jpg
#   inflating: content/Positive/15076_1.jpg
#   inflating: content/Positive/15077_1.jpg
#   inflating: content/Positive/15078_1.jpg
#   inflating: content/Positive/15079_1.jpg
#   inflating: content/Positive/15080_1.jpg
#   inflating: content/Positive/15081_1.jpg
#   inflating: content/Positive/15082_1.jpg
#   inflating: content/Positive/15083_1.jpg
#   inflating: content/Positive/15084_1.jpg
#   inflating: content/Positive/15085_1.jpg
#   inflating: content/Positive/15086_1.jpg
#   inflating: content/Positive/15087_1.jpg
#   inflating: content/Positive/15088_1.jpg
#   inflating: content/Positive/15089_1.jpg
#   inflating: content/Positive/15090_1.jpg
#   inflating: content/Positive/15091_1.jpg
#   inflating: content/Positive/15092_1.jpg
#   inflating: content/Positive/15093_1.jpg
#   inflating: content/Positive/15094_1.jpg
#   inflating: content/Positive/15095_1.jpg
#   inflating: content/Positive/15096_1.jpg
#   inflating: content/Positive/15097_1.jpg
#   inflating: content/Positive/15098_1.jpg
#   inflating: content/Positive/15099_1.jpg
#   inflating: content/Positive/15100_1.jpg
#   inflating: content/Positive/15101_1.jpg
#   inflating: content/Positive/15102_1.jpg
#   inflating: content/Positive/15103_1.jpg
#   inflating: content/Positive/15104_1.jpg
#   inflating: content/Positive/15105_1.jpg
#   inflating: content/Positive/15106_1.jpg
#   inflating: content/Positive/15107_1.jpg
#   inflating: content/Positive/15108_1.jpg
#   inflating: content/Positive/15109_1.jpg
#   inflating: content/Positive/15110_1.jpg
#   inflating: content/Positive/15111_1.jpg
#   inflating: content/Positive/15112_1.jpg
#   inflating: content/Positive/15113_1.jpg
#   inflating: content/Positive/15114_1.jpg
#   inflating: content/Positive/15115_1.jpg
#   inflating: content/Positive/15116_1.jpg
#   inflating: content/Positive/15117_1.jpg
#   inflating: content/Positive/15118_1.jpg
#   inflating: content/Positive/15119_1.jpg
#   inflating: content/Positive/15120_1.jpg
#   inflating: content/Positive/15121_1.jpg
#   inflating: content/Positive/15122_1.jpg
#   inflating: content/Positive/15123_1.jpg
#   inflating: content/Positive/15124_1.jpg
#   inflating: content/Positive/15125_1.jpg
#   inflating: content/Positive/15126_1.jpg
#   inflating: content/Positive/15127_1.jpg
#   inflating: content/Positive/15128_1.jpg
#   inflating: content/Positive/15129_1.jpg
#   inflating: content/Positive/15130_1.jpg
#   inflating: content/Positive/15131_1.jpg
#   inflating: content/Positive/15132_1.jpg
#   inflating: content/Positive/15133_1.jpg
#   inflating: content/Positive/15134_1.jpg
#   inflating: content/Positive/15135_1.jpg
#   inflating: content/Positive/15136_1.jpg
#   inflating: content/Positive/15137_1.jpg
#   inflating: content/Positive/15138_1.jpg
#   inflating: content/Positive/15139_1.jpg
#   inflating: content/Positive/15140_1.jpg
#   inflating: content/Positive/15141_1.jpg
#   inflating: content/Positive/15142_1.jpg
#   inflating: content/Positive/15143_1.jpg
#   inflating: content/Positive/15144_1.jpg
#   inflating: content/Positive/15145_1.jpg
#   inflating: content/Positive/15146_1.jpg
#   inflating: content/Positive/15147_1.jpg
#   inflating: content/Positive/15148_1.jpg
#   inflating: content/Positive/15149_1.jpg
#   inflating: content/Positive/15150_1.jpg
#   inflating: content/Positive/15151_1.jpg
#   inflating: content/Positive/15152_1.jpg
#   inflating: content/Positive/15153_1.jpg
#   inflating: content/Positive/15154_1.jpg
#   inflating: content/Positive/15155_1.jpg
#   inflating: content/Positive/15156_1.jpg
#   inflating: content/Positive/15157_1.jpg
#   inflating: content/Positive/15158_1.jpg
#   inflating: content/Positive/15159_1.jpg
#   inflating: content/Positive/15160_1.jpg
#   inflating: content/Positive/15161_1.jpg
#   inflating: content/Positive/15162_1.jpg
#   inflating: content/Positive/15163_1.jpg
#   inflating: content/Positive/15164_1.jpg
#   inflating: content/Positive/15165_1.jpg
#   inflating: content/Positive/15166_1.jpg
#   inflating: content/Positive/15167_1.jpg
#   inflating: content/Positive/15168_1.jpg
#   inflating: content/Positive/15169_1.jpg
#   inflating: content/Positive/15170_1.jpg
#   inflating: content/Positive/15171_1.jpg
#   inflating: content/Positive/15172_1.jpg
#   inflating: content/Positive/15173_1.jpg
#   inflating: content/Positive/15174_1.jpg
#   inflating: content/Positive/15175_1.jpg
#   inflating: content/Positive/15176_1.jpg
#   inflating: content/Positive/15177_1.jpg
#   inflating: content/Positive/15178_1.jpg
#   inflating: content/Positive/15179_1.jpg
#   inflating: content/Positive/15180_1.jpg
#   inflating: content/Positive/15181_1.jpg
#   inflating: content/Positive/15182_1.jpg
#   inflating: content/Positive/15183_1.jpg
#   inflating: content/Positive/15184_1.jpg
#   inflating: content/Positive/15185_1.jpg
#   inflating: content/Positive/15186_1.jpg
#   inflating: content/Positive/15187_1.jpg
#   inflating: content/Positive/15188_1.jpg
#   inflating: content/Positive/15189_1.jpg
#   inflating: content/Positive/15190_1.jpg
#   inflating: content/Positive/15191_1.jpg
#   inflating: content/Positive/15192_1.jpg
#   inflating: content/Positive/15193_1.jpg
#   inflating: content/Positive/15194_1.jpg
#   inflating: content/Positive/15195_1.jpg
#   inflating: content/Positive/15196_1.jpg
#   inflating: content/Positive/15197_1.jpg
#   inflating: content/Positive/15198_1.jpg
#   inflating: content/Positive/15199_1.jpg
#   inflating: content/Positive/15200_1.jpg
#   inflating: content/Positive/15201_1.jpg
#   inflating: content/Positive/15202_1.jpg
#   inflating: content/Positive/15203_1.jpg
#   inflating: content/Positive/15204_1.jpg
#   inflating: content/Positive/15205_1.jpg
#   inflating: content/Positive/15206_1.jpg
#   inflating: content/Positive/15207_1.jpg
#   inflating: content/Positive/15208_1.jpg
#   inflating: content/Positive/15209_1.jpg
#   inflating: content/Positive/15210_1.jpg
#   inflating: content/Positive/15211_1.jpg
#   inflating: content/Positive/15212_1.jpg
#   inflating: content/Positive/15213_1.jpg
#   inflating: content/Positive/15214_1.jpg
#   inflating: content/Positive/15215_1.jpg
#   inflating: content/Positive/15216_1.jpg
#   inflating: content/Positive/15217_1.jpg
#   inflating: content/Positive/15218_1.jpg
#   inflating: content/Positive/15219_1.jpg
#   inflating: content/Positive/15220_1.jpg
#   inflating: content/Positive/15221_1.jpg
#   inflating: content/Positive/15222_1.jpg
#   inflating: content/Positive/15223_1.jpg
#   inflating: content/Positive/15224_1.jpg
#   inflating: content/Positive/15225_1.jpg
#   inflating: content/Positive/15226_1.jpg
#   inflating: content/Positive/15227_1.jpg
#   inflating: content/Positive/15228_1.jpg
#   inflating: content/Positive/15229_1.jpg
#   inflating: content/Positive/15230_1.jpg
#   inflating: content/Positive/15231_1.jpg
#   inflating: content/Positive/15232_1.jpg
#   inflating: content/Positive/15233_1.jpg
#   inflating: content/Positive/15234_1.jpg
#   inflating: content/Positive/15235_1.jpg
#   inflating: content/Positive/15236_1.jpg
#   inflating: content/Positive/15237_1.jpg
#   inflating: content/Positive/15238_1.jpg
#   inflating: content/Positive/15239_1.jpg
#   inflating: content/Positive/15240_1.jpg
#   inflating: content/Positive/15241_1.jpg
#   inflating: content/Positive/15242_1.jpg
#   inflating: content/Positive/15243_1.jpg
#   inflating: content/Positive/15244_1.jpg
#   inflating: content/Positive/15245_1.jpg
#   inflating: content/Positive/15246_1.jpg
#   inflating: content/Positive/15247_1.jpg
#   inflating: content/Positive/15248_1.jpg
#   inflating: content/Positive/15249_1.jpg
#   inflating: content/Positive/15250_1.jpg
#   inflating: content/Positive/15251_1.jpg
#   inflating: content/Positive/15252_1.jpg
#   inflating: content/Positive/15253_1.jpg
#   inflating: content/Positive/15254_1.jpg
#   inflating: content/Positive/15255_1.jpg
#   inflating: content/Positive/15256_1.jpg
#   inflating: content/Positive/15257_1.jpg
#   inflating: content/Positive/15258_1.jpg
#   inflating: content/Positive/15259_1.jpg
#   inflating: content/Positive/15260_1.jpg
#   inflating: content/Positive/15261_1.jpg
#   inflating: content/Positive/15262_1.jpg
#   inflating: content/Positive/15263_1.jpg
#   inflating: content/Positive/15264_1.jpg
#   inflating: content/Positive/15265_1.jpg
#   inflating: content/Positive/15266_1.jpg
#   inflating: content/Positive/15267_1.jpg
#   inflating: content/Positive/15268_1.jpg
#   inflating: content/Positive/15269_1.jpg
#   inflating: content/Positive/15270_1.jpg
#   inflating: content/Positive/15271_1.jpg
#   inflating: content/Positive/15272_1.jpg
#   inflating: content/Positive/15273_1.jpg
#   inflating: content/Positive/15274_1.jpg
#   inflating: content/Positive/15275_1.jpg
#   inflating: content/Positive/15276_1.jpg
#   inflating: content/Positive/15277_1.jpg
#   inflating: content/Positive/15278_1.jpg
#   inflating: content/Positive/15279_1.jpg
#   inflating: content/Positive/15280_1.jpg
#   inflating: content/Positive/15281_1.jpg
#   inflating: content/Positive/15282_1.jpg
#   inflating: content/Positive/15283_1.jpg
#   inflating: content/Positive/15284_1.jpg
#   inflating: content/Positive/15285_1.jpg
#   inflating: content/Positive/15286_1.jpg
#   inflating: content/Positive/15287_1.jpg
#   inflating: content/Positive/15288_1.jpg
#   inflating: content/Positive/15289_1.jpg
#   inflating: content/Positive/15290_1.jpg
#   inflating: content/Positive/15291_1.jpg
#   inflating: content/Positive/15292_1.jpg
#   inflating: content/Positive/15293_1.jpg
#   inflating: content/Positive/15294_1.jpg
#   inflating: content/Positive/15295_1.jpg
#   inflating: content/Positive/15296_1.jpg
#   inflating: content/Positive/15297_1.jpg
#   inflating: content/Positive/15298_1.jpg
#   inflating: content/Positive/15299_1.jpg
#   inflating: content/Positive/15300_1.jpg
#   inflating: content/Positive/15301_1.jpg
#   inflating: content/Positive/15302_1.jpg
#   inflating: content/Positive/15303_1.jpg
#   inflating: content/Positive/15304_1.jpg
#   inflating: content/Positive/15305_1.jpg
#   inflating: content/Positive/15306_1.jpg
#   inflating: content/Positive/15307_1.jpg
#   inflating: content/Positive/15308_1.jpg
#   inflating: content/Positive/15309_1.jpg
#   inflating: content/Positive/15310_1.jpg
#   inflating: content/Positive/15311_1.jpg
#   inflating: content/Positive/15312_1.jpg
#   inflating: content/Positive/15313_1.jpg
#   inflating: content/Positive/15314_1.jpg
#   inflating: content/Positive/15315_1.jpg
#   inflating: content/Positive/15316_1.jpg
#   inflating: content/Positive/15317_1.jpg
#   inflating: content/Positive/15318_1.jpg
#   inflating: content/Positive/15319_1.jpg
#   inflating: content/Positive/15320_1.jpg
#   inflating: content/Positive/15321_1.jpg
#   inflating: content/Positive/15322_1.jpg
#   inflating: content/Positive/15323_1.jpg
#   inflating: content/Positive/15324_1.jpg
#   inflating: content/Positive/15325_1.jpg
#   inflating: content/Positive/15326_1.jpg
#   inflating: content/Positive/15327_1.jpg
#   inflating: content/Positive/15328_1.jpg
#   inflating: content/Positive/15329_1.jpg
#   inflating: content/Positive/15330_1.jpg
#   inflating: content/Positive/15331_1.jpg
#   inflating: content/Positive/15332_1.jpg
#   inflating: content/Positive/15333_1.jpg
#   inflating: content/Positive/15334_1.jpg
#   inflating: content/Positive/15335_1.jpg
#   inflating: content/Positive/15336_1.jpg
#   inflating: content/Positive/15337_1.jpg
#   inflating: content/Positive/15338_1.jpg
#   inflating: content/Positive/15339_1.jpg
#   inflating: content/Positive/15340_1.jpg
#   inflating: content/Positive/15341_1.jpg
#   inflating: content/Positive/15342_1.jpg
#   inflating: content/Positive/15343_1.jpg
#   inflating: content/Positive/15344_1.jpg
#   inflating: content/Positive/15345_1.jpg
#   inflating: content/Positive/15346_1.jpg
#   inflating: content/Positive/15347_1.jpg
#   inflating: content/Positive/15348_1.jpg
#   inflating: content/Positive/15349_1.jpg
#   inflating: content/Positive/15350_1.jpg
#   inflating: content/Positive/15351_1.jpg
#   inflating: content/Positive/15352_1.jpg
#   inflating: content/Positive/15353_1.jpg
#   inflating: content/Positive/15354_1.jpg
#   inflating: content/Positive/15355_1.jpg
#   inflating: content/Positive/15356_1.jpg
#   inflating: content/Positive/15357_1.jpg
#   inflating: content/Positive/15358_1.jpg
#   inflating: content/Positive/15359_1.jpg
#   inflating: content/Positive/15360_1.jpg
#   inflating: content/Positive/15361_1.jpg
#   inflating: content/Positive/15362_1.jpg
#   inflating: content/Positive/15363_1.jpg
#   inflating: content/Positive/15364_1.jpg
#   inflating: content/Positive/15365_1.jpg
#   inflating: content/Positive/15366_1.jpg
#   inflating: content/Positive/15367_1.jpg
#   inflating: content/Positive/15368_1.jpg
#   inflating: content/Positive/15369_1.jpg
#   inflating: content/Positive/15370_1.jpg
#   inflating: content/Positive/15371_1.jpg
#   inflating: content/Positive/15372_1.jpg
#   inflating: content/Positive/15373_1.jpg
#   inflating: content/Positive/15374_1.jpg
#   inflating: content/Positive/15375_1.jpg
#   inflating: content/Positive/15376_1.jpg
#   inflating: content/Positive/15377_1.jpg
#   inflating: content/Positive/15378_1.jpg
#   inflating: content/Positive/15379_1.jpg
#   inflating: content/Positive/15380_1.jpg
#   inflating: content/Positive/15381_1.jpg
#   inflating: content/Positive/15382_1.jpg
#   inflating: content/Positive/15383_1.jpg
#   inflating: content/Positive/15384_1.jpg
#   inflating: content/Positive/15385_1.jpg
#   inflating: content/Positive/15386_1.jpg
#   inflating: content/Positive/15387_1.jpg
#   inflating: content/Positive/15388_1.jpg
#   inflating: content/Positive/15389_1.jpg
#   inflating: content/Positive/15390_1.jpg
#   inflating: content/Positive/15391_1.jpg
#   inflating: content/Positive/15392_1.jpg
#   inflating: content/Positive/15393_1.jpg
#   inflating: content/Positive/15394_1.jpg
#   inflating: content/Positive/15395_1.jpg
#   inflating: content/Positive/15396_1.jpg
#   inflating: content/Positive/15397_1.jpg
#   inflating: content/Positive/15398_1.jpg
#   inflating: content/Positive/15399_1.jpg
#   inflating: content/Positive/15400_1.jpg
#   inflating: content/Positive/15401_1.jpg
#   inflating: content/Positive/15402_1.jpg
#   inflating: content/Positive/15403_1.jpg
#   inflating: content/Positive/15404_1.jpg
#   inflating: content/Positive/15405_1.jpg
#   inflating: content/Positive/15406_1.jpg
#   inflating: content/Positive/15407_1.jpg
#   inflating: content/Positive/15408_1.jpg
#   inflating: content/Positive/15409_1.jpg
#   inflating: content/Positive/15410_1.jpg
#   inflating: content/Positive/15411_1.jpg
#   inflating: content/Positive/15412_1.jpg
#   inflating: content/Positive/15413_1.jpg
#   inflating: content/Positive/15414_1.jpg
#   inflating: content/Positive/15415_1.jpg
#   inflating: content/Positive/15416_1.jpg
#   inflating: content/Positive/15417_1.jpg
#   inflating: content/Positive/15418_1.jpg
#   inflating: content/Positive/15419_1.jpg
#   inflating: content/Positive/15420_1.jpg
#   inflating: content/Positive/15421_1.jpg
#   inflating: content/Positive/15422_1.jpg
#   inflating: content/Positive/15423_1.jpg
#   inflating: content/Positive/15424_1.jpg
#   inflating: content/Positive/15425_1.jpg
#   inflating: content/Positive/15426_1.jpg
#   inflating: content/Positive/15427_1.jpg
#   inflating: content/Positive/15428_1.jpg
#   inflating: content/Positive/15429_1.jpg
#   inflating: content/Positive/15430_1.jpg
#   inflating: content/Positive/15431_1.jpg
#   inflating: content/Positive/15432_1.jpg
#   inflating: content/Positive/15433_1.jpg
#   inflating: content/Positive/15434_1.jpg
#   inflating: content/Positive/15435_1.jpg
#   inflating: content/Positive/15436_1.jpg
#   inflating: content/Positive/15437_1.jpg
#   inflating: content/Positive/15438_1.jpg
#   inflating: content/Positive/15439_1.jpg
#   inflating: content/Positive/15440_1.jpg
#   inflating: content/Positive/15441_1.jpg
#   inflating: content/Positive/15442_1.jpg
#   inflating: content/Positive/15443_1.jpg
#   inflating: content/Positive/15444_1.jpg
#   inflating: content/Positive/15445_1.jpg
#   inflating: content/Positive/15446_1.jpg
#   inflating: content/Positive/15447_1.jpg
#   inflating: content/Positive/15448_1.jpg
#   inflating: content/Positive/15449_1.jpg
#   inflating: content/Positive/15450_1.jpg
#   inflating: content/Positive/15451_1.jpg
#   inflating: content/Positive/15452_1.jpg
#   inflating: content/Positive/15453_1.jpg
#   inflating: content/Positive/15454_1.jpg
#   inflating: content/Positive/15455_1.jpg
#   inflating: content/Positive/15456_1.jpg
#   inflating: content/Positive/15457_1.jpg
#   inflating: content/Positive/15458_1.jpg
#   inflating: content/Positive/15459_1.jpg
#   inflating: content/Positive/15460_1.jpg
#   inflating: content/Positive/15461_1.jpg
#   inflating: content/Positive/15462_1.jpg
#   inflating: content/Positive/15463_1.jpg
#   inflating: content/Positive/15464_1.jpg
#   inflating: content/Positive/15465_1.jpg
#   inflating: content/Positive/15466_1.jpg
#   inflating: content/Positive/15467_1.jpg
#   inflating: content/Positive/15468_1.jpg
#   inflating: content/Positive/15469_1.jpg
#   inflating: content/Positive/15470_1.jpg
#   inflating: content/Positive/15471_1.jpg
#   inflating: content/Positive/15472_1.jpg
#   inflating: content/Positive/15473_1.jpg
#   inflating: content/Positive/15474_1.jpg
#   inflating: content/Positive/15475_1.jpg
#   inflating: content/Positive/15476_1.jpg
#   inflating: content/Positive/15477_1.jpg
#   inflating: content/Positive/15478_1.jpg
#   inflating: content/Positive/15479_1.jpg
#   inflating: content/Positive/15480_1.jpg
#   inflating: content/Positive/15481_1.jpg
#   inflating: content/Positive/15482_1.jpg
#   inflating: content/Positive/15483_1.jpg
#   inflating: content/Positive/15484_1.jpg
#   inflating: content/Positive/15485_1.jpg
#   inflating: content/Positive/15486_1.jpg
#   inflating: content/Positive/15487_1.jpg
#   inflating: content/Positive/15488_1.jpg
#   inflating: content/Positive/15489_1.jpg
#   inflating: content/Positive/15490_1.jpg
#   inflating: content/Positive/15491_1.jpg
#   inflating: content/Positive/15492_1.jpg
#   inflating: content/Positive/15493_1.jpg
#   inflating: content/Positive/15494_1.jpg
#   inflating: content/Positive/15495_1.jpg
#   inflating: content/Positive/15496_1.jpg
#   inflating: content/Positive/15497_1.jpg
#   inflating: content/Positive/15498_1.jpg
#   inflating: content/Positive/15499_1.jpg
#   inflating: content/Positive/15500_1.jpg
#   inflating: content/Positive/15501_1.jpg
#   inflating: content/Positive/15502_1.jpg
#   inflating: content/Positive/15503_1.jpg
#   inflating: content/Positive/15504_1.jpg
#   inflating: content/Positive/15505_1.jpg
#   inflating: content/Positive/15506_1.jpg
#   inflating: content/Positive/15507_1.jpg
#   inflating: content/Positive/15508_1.jpg
#   inflating: content/Positive/15509_1.jpg
#   inflating: content/Positive/15510_1.jpg
#   inflating: content/Positive/15511_1.jpg
#   inflating: content/Positive/15512_1.jpg
#   inflating: content/Positive/15513_1.jpg
#   inflating: content/Positive/15514_1.jpg
#   inflating: content/Positive/15515_1.jpg
#   inflating: content/Positive/15516_1.jpg
#   inflating: content/Positive/15517_1.jpg
#   inflating: content/Positive/15518_1.jpg
#   inflating: content/Positive/15519_1.jpg
#   inflating: content/Positive/15520_1.jpg
#   inflating: content/Positive/15521_1.jpg
#   inflating: content/Positive/15522_1.jpg
#   inflating: content/Positive/15523_1.jpg
#   inflating: content/Positive/15524_1.jpg
#   inflating: content/Positive/15525_1.jpg
#   inflating: content/Positive/15526_1.jpg
#   inflating: content/Positive/15527_1.jpg
#   inflating: content/Positive/15528_1.jpg
#   inflating: content/Positive/15529_1.jpg
#   inflating: content/Positive/15530_1.jpg
#   inflating: content/Positive/15531_1.jpg
#   inflating: content/Positive/15532_1.jpg
#   inflating: content/Positive/15533_1.jpg
#   inflating: content/Positive/15534_1.jpg
#   inflating: content/Positive/15535_1.jpg
#   inflating: content/Positive/15536_1.jpg
#   inflating: content/Positive/15537_1.jpg
#   inflating: content/Positive/15538_1.jpg
#   inflating: content/Positive/15539_1.jpg
#   inflating: content/Positive/15540_1.jpg
#   inflating: content/Positive/15541_1.jpg
#   inflating: content/Positive/15542_1.jpg
#   inflating: content/Positive/15543_1.jpg
#   inflating: content/Positive/15544_1.jpg
#   inflating: content/Positive/15545_1.jpg
#   inflating: content/Positive/15546_1.jpg
#   inflating: content/Positive/15547_1.jpg
#   inflating: content/Positive/15548_1.jpg
#   inflating: content/Positive/15549_1.jpg
#   inflating: content/Positive/15550_1.jpg
#   inflating: content/Positive/15551_1.jpg
#   inflating: content/Positive/15552_1.jpg
#   inflating: content/Positive/15553_1.jpg
#   inflating: content/Positive/15554_1.jpg
#   inflating: content/Positive/15555_1.jpg
#   inflating: content/Positive/15556_1.jpg
#   inflating: content/Positive/15557_1.jpg
#   inflating: content/Positive/15558_1.jpg
#   inflating: content/Positive/15559_1.jpg
#   inflating: content/Positive/15560_1.jpg
#   inflating: content/Positive/15561_1.jpg
#   inflating: content/Positive/15562_1.jpg
#   inflating: content/Positive/15563_1.jpg
#   inflating: content/Positive/15564_1.jpg
#   inflating: content/Positive/15565_1.jpg
#   inflating: content/Positive/15566_1.jpg
#   inflating: content/Positive/15567_1.jpg
#   inflating: content/Positive/15568_1.jpg
#   inflating: content/Positive/15569_1.jpg
#   inflating: content/Positive/15570_1.jpg
#   inflating: content/Positive/15571_1.jpg
#   inflating: content/Positive/15572_1.jpg
#   inflating: content/Positive/15573_1.jpg
#   inflating: content/Positive/15574_1.jpg
#   inflating: content/Positive/15575_1.jpg
#   inflating: content/Positive/15576_1.jpg
#   inflating: content/Positive/15577_1.jpg
#   inflating: content/Positive/15578_1.jpg
#   inflating: content/Positive/15579_1.jpg
#   inflating: content/Positive/15580_1.jpg
#   inflating: content/Positive/15581_1.jpg
#   inflating: content/Positive/15582_1.jpg
#   inflating: content/Positive/15583_1.jpg
#   inflating: content/Positive/15584_1.jpg
#   inflating: content/Positive/15585_1.jpg
#   inflating: content/Positive/15586_1.jpg
#   inflating: content/Positive/15587_1.jpg
#   inflating: content/Positive/15588_1.jpg
#   inflating: content/Positive/15589_1.jpg
#   inflating: content/Positive/15590_1.jpg
#   inflating: content/Positive/15591_1.jpg
#   inflating: content/Positive/15592_1.jpg
#   inflating: content/Positive/15593_1.jpg
#   inflating: content/Positive/15594_1.jpg
#   inflating: content/Positive/15595_1.jpg
#   inflating: content/Positive/15596_1.jpg
#   inflating: content/Positive/15597_1.jpg
#   inflating: content/Positive/15598_1.jpg
#   inflating: content/Positive/15599_1.jpg
#   inflating: content/Positive/15600_1.jpg
#   inflating: content/Positive/15601_1.jpg
#   inflating: content/Positive/15602_1.jpg
#   inflating: content/Positive/15603_1.jpg
#   inflating: content/Positive/15604_1.jpg
#   inflating: content/Positive/15605_1.jpg
#   inflating: content/Positive/15606_1.jpg
#   inflating: content/Positive/15607_1.jpg
#   inflating: content/Positive/15608_1.jpg
#   inflating: content/Positive/15609_1.jpg
#   inflating: content/Positive/15610_1.jpg
#   inflating: content/Positive/15611_1.jpg
#   inflating: content/Positive/15612_1.jpg
#   inflating: content/Positive/15613_1.jpg
#   inflating: content/Positive/15614_1.jpg
#   inflating: content/Positive/15615_1.jpg
#   inflating: content/Positive/15616_1.jpg
#   inflating: content/Positive/15617_1.jpg
#   inflating: content/Positive/15618_1.jpg
#   inflating: content/Positive/15619_1.jpg
#   inflating: content/Positive/15620_1.jpg
#   inflating: content/Positive/15621_1.jpg
#   inflating: content/Positive/15622_1.jpg
#   inflating: content/Positive/15623_1.jpg
#   inflating: content/Positive/15624_1.jpg
#   inflating: content/Positive/15625_1.jpg
#   inflating: content/Positive/15626_1.jpg
#   inflating: content/Positive/15627_1.jpg
#   inflating: content/Positive/15628_1.jpg
#   inflating: content/Positive/15629_1.jpg
#   inflating: content/Positive/15630_1.jpg
#   inflating: content/Positive/15631_1.jpg
#   inflating: content/Positive/15632_1.jpg
#   inflating: content/Positive/15633_1.jpg
#   inflating: content/Positive/15634_1.jpg
#   inflating: content/Positive/15635_1.jpg
#   inflating: content/Positive/15636_1.jpg
#   inflating: content/Positive/15637_1.jpg
#   inflating: content/Positive/15638_1.jpg
#   inflating: content/Positive/15639_1.jpg
#   inflating: content/Positive/15640_1.jpg
#   inflating: content/Positive/15641_1.jpg
#   inflating: content/Positive/15642_1.jpg
#   inflating: content/Positive/15643_1.jpg
#   inflating: content/Positive/15644_1.jpg
#   inflating: content/Positive/15645_1.jpg
#   inflating: content/Positive/15646_1.jpg
#   inflating: content/Positive/15647_1.jpg
#   inflating: content/Positive/15648_1.jpg
#   inflating: content/Positive/15649_1.jpg
#   inflating: content/Positive/15650_1.jpg
#   inflating: content/Positive/15651_1.jpg
#   inflating: content/Positive/15652_1.jpg
#   inflating: content/Positive/15653_1.jpg
#   inflating: content/Positive/15654_1.jpg
#   inflating: content/Positive/15655_1.jpg
#   inflating: content/Positive/15656_1.jpg
#   inflating: content/Positive/15657_1.jpg
#   inflating: content/Positive/15658_1.jpg
#   inflating: content/Positive/15659_1.jpg
#   inflating: content/Positive/15660_1.jpg
#   inflating: content/Positive/15661_1.jpg
#   inflating: content/Positive/15662_1.jpg
#   inflating: content/Positive/15663_1.jpg
#   inflating: content/Positive/15664_1.jpg
#   inflating: content/Positive/15665_1.jpg
#   inflating: content/Positive/15666_1.jpg
#   inflating: content/Positive/15667_1.jpg
#   inflating: content/Positive/15668_1.jpg
#   inflating: content/Positive/15669_1.jpg
#   inflating: content/Positive/15670_1.jpg
#   inflating: content/Positive/15671_1.jpg
#   inflating: content/Positive/15672_1.jpg
#   inflating: content/Positive/15673_1.jpg
#   inflating: content/Positive/15674_1.jpg
#   inflating: content/Positive/15675_1.jpg
#   inflating: content/Positive/15676_1.jpg
#   inflating: content/Positive/15677_1.jpg
#   inflating: content/Positive/15678_1.jpg
#   inflating: content/Positive/15679_1.jpg
#   inflating: content/Positive/15680_1.jpg
#   inflating: content/Positive/15681_1.jpg
#   inflating: content/Positive/15682_1.jpg
#   inflating: content/Positive/15683_1.jpg
#   inflating: content/Positive/15684_1.jpg
#   inflating: content/Positive/15685_1.jpg
#   inflating: content/Positive/15686_1.jpg
#   inflating: content/Positive/15687_1.jpg
#   inflating: content/Positive/15688_1.jpg
#   inflating: content/Positive/15689_1.jpg
#   inflating: content/Positive/15690_1.jpg
#   inflating: content/Positive/15691_1.jpg
#   inflating: content/Positive/15692_1.jpg
#   inflating: content/Positive/15693_1.jpg
#   inflating: content/Positive/15694_1.jpg
#   inflating: content/Positive/15695_1.jpg
#   inflating: content/Positive/15696_1.jpg
#   inflating: content/Positive/15697_1.jpg
#   inflating: content/Positive/15698_1.jpg
#   inflating: content/Positive/15699_1.jpg
#   inflating: content/Positive/15700_1.jpg
#   inflating: content/Positive/15701_1.jpg
#   inflating: content/Positive/15702_1.jpg
#   inflating: content/Positive/15703_1.jpg
#   inflating: content/Positive/15704_1.jpg
#   inflating: content/Positive/15705_1.jpg
#   inflating: content/Positive/15706_1.jpg
#   inflating: content/Positive/15707_1.jpg
#   inflating: content/Positive/15708_1.jpg
#   inflating: content/Positive/15709_1.jpg
#   inflating: content/Positive/15710_1.jpg
#   inflating: content/Positive/15711_1.jpg
#   inflating: content/Positive/15712_1.jpg
#   inflating: content/Positive/15713_1.jpg
#   inflating: content/Positive/15714_1.jpg
#   inflating: content/Positive/15715_1.jpg
#   inflating: content/Positive/15716_1.jpg
#   inflating: content/Positive/15717_1.jpg
#   inflating: content/Positive/15718_1.jpg
#   inflating: content/Positive/15719_1.jpg
#   inflating: content/Positive/15720_1.jpg
#   inflating: content/Positive/15721_1.jpg
#   inflating: content/Positive/15722_1.jpg
#   inflating: content/Positive/15723_1.jpg
#   inflating: content/Positive/15724_1.jpg
#   inflating: content/Positive/15725_1.jpg
#   inflating: content/Positive/15726_1.jpg
#   inflating: content/Positive/15727_1.jpg
#   inflating: content/Positive/15728_1.jpg
#   inflating: content/Positive/15729_1.jpg
#   inflating: content/Positive/15730_1.jpg
#   inflating: content/Positive/15731_1.jpg
#   inflating: content/Positive/15732_1.jpg
#   inflating: content/Positive/15733_1.jpg
#   inflating: content/Positive/15734_1.jpg
#   inflating: content/Positive/15735_1.jpg
#   inflating: content/Positive/15736_1.jpg
#   inflating: content/Positive/15737_1.jpg
#   inflating: content/Positive/15738_1.jpg
#   inflating: content/Positive/15739_1.jpg
#   inflating: content/Positive/15740_1.jpg
#   inflating: content/Positive/15741_1.jpg
#   inflating: content/Positive/15742_1.jpg
#   inflating: content/Positive/15743_1.jpg
#   inflating: content/Positive/15744_1.jpg
#   inflating: content/Positive/15745_1.jpg
#   inflating: content/Positive/15746_1.jpg
#   inflating: content/Positive/15747_1.jpg
#   inflating: content/Positive/15748_1.jpg
#   inflating: content/Positive/15749_1.jpg
#   inflating: content/Positive/15750_1.jpg
#   inflating: content/Positive/15751_1.jpg
#   inflating: content/Positive/15752_1.jpg
#   inflating: content/Positive/15753_1.jpg
#   inflating: content/Positive/15754_1.jpg
#   inflating: content/Positive/15755_1.jpg
#   inflating: content/Positive/15756_1.jpg
#   inflating: content/Positive/15757_1.jpg
#   inflating: content/Positive/15758_1.jpg
#   inflating: content/Positive/15759_1.jpg
#   inflating: content/Positive/15760_1.jpg
#   inflating: content/Positive/15761_1.jpg
#   inflating: content/Positive/15762_1.jpg
#   inflating: content/Positive/15763_1.jpg
#   inflating: content/Positive/15764_1.jpg
#   inflating: content/Positive/15765_1.jpg
#   inflating: content/Positive/15766_1.jpg
#   inflating: content/Positive/15767_1.jpg
#   inflating: content/Positive/15768_1.jpg
#   inflating: content/Positive/15769_1.jpg
#   inflating: content/Positive/15770_1.jpg
#   inflating: content/Positive/15771_1.jpg
#   inflating: content/Positive/15772_1.jpg
#   inflating: content/Positive/15773_1.jpg
#   inflating: content/Positive/15774_1.jpg
#   inflating: content/Positive/15775_1.jpg
#   inflating: content/Positive/15776_1.jpg
#   inflating: content/Positive/15777_1.jpg
#   inflating: content/Positive/15778_1.jpg
#   inflating: content/Positive/15779_1.jpg
#   inflating: content/Positive/15780_1.jpg
#   inflating: content/Positive/15781_1.jpg
#   inflating: content/Positive/15782_1.jpg
#   inflating: content/Positive/15783_1.jpg
#   inflating: content/Positive/15784_1.jpg
#   inflating: content/Positive/15785_1.jpg
#   inflating: content/Positive/15786_1.jpg
#   inflating: content/Positive/15787_1.jpg
#   inflating: content/Positive/15788_1.jpg
#   inflating: content/Positive/15789_1.jpg
#   inflating: content/Positive/15790_1.jpg
#   inflating: content/Positive/15791_1.jpg
#   inflating: content/Positive/15792_1.jpg
#   inflating: content/Positive/15793_1.jpg
#   inflating: content/Positive/15794_1.jpg
#   inflating: content/Positive/15795_1.jpg
#   inflating: content/Positive/15796_1.jpg
#   inflating: content/Positive/15797_1.jpg
#   inflating: content/Positive/15798_1.jpg
#   inflating: content/Positive/15799_1.jpg
#   inflating: content/Positive/15800_1.jpg
#   inflating: content/Positive/15801_1.jpg
#   inflating: content/Positive/15802_1.jpg
#   inflating: content/Positive/15803_1.jpg
#   inflating: content/Positive/15804_1.jpg
#   inflating: content/Positive/15805_1.jpg
#   inflating: content/Positive/15806_1.jpg
#   inflating: content/Positive/15807_1.jpg
#   inflating: content/Positive/15808_1.jpg
#   inflating: content/Positive/15809_1.jpg
#   inflating: content/Positive/15810_1.jpg
#   inflating: content/Positive/15811_1.jpg
#   inflating: content/Positive/15812_1.jpg
#   inflating: content/Positive/15813_1.jpg
#   inflating: content/Positive/15814_1.jpg
#   inflating: content/Positive/15815_1.jpg
#   inflating: content/Positive/15816_1.jpg
#   inflating: content/Positive/15817_1.jpg
#   inflating: content/Positive/15818_1.jpg
#   inflating: content/Positive/15819_1.jpg
#   inflating: content/Positive/15820_1.jpg
#   inflating: content/Positive/15821_1.jpg
#   inflating: content/Positive/15822_1.jpg
#   inflating: content/Positive/15823_1.jpg
#   inflating: content/Positive/15824_1.jpg
#   inflating: content/Positive/15825_1.jpg
#   inflating: content/Positive/15826_1.jpg
#   inflating: content/Positive/15827_1.jpg
#   inflating: content/Positive/15828_1.jpg
#   inflating: content/Positive/15829_1.jpg
#   inflating: content/Positive/15830_1.jpg
#   inflating: content/Positive/15831_1.jpg
#   inflating: content/Positive/15832_1.jpg
#   inflating: content/Positive/15833_1.jpg
#   inflating: content/Positive/15834_1.jpg
#   inflating: content/Positive/15835_1.jpg
#   inflating: content/Positive/15836_1.jpg
#   inflating: content/Positive/15837_1.jpg
#   inflating: content/Positive/15838_1.jpg
#   inflating: content/Positive/15839_1.jpg
#   inflating: content/Positive/15840_1.jpg
#   inflating: content/Positive/15841_1.jpg
#   inflating: content/Positive/15842_1.jpg
#   inflating: content/Positive/15843_1.jpg
#   inflating: content/Positive/15844_1.jpg
#   inflating: content/Positive/15845_1.jpg
#   inflating: content/Positive/15846_1.jpg
#   inflating: content/Positive/15847_1.jpg
#   inflating: content/Positive/15848_1.jpg
#   inflating: content/Positive/15849_1.jpg
#   inflating: content/Positive/15850_1.jpg
#   inflating: content/Positive/15851_1.jpg
#   inflating: content/Positive/15852_1.jpg
#   inflating: content/Positive/15853_1.jpg
#   inflating: content/Positive/15854_1.jpg
#   inflating: content/Positive/15855_1.jpg
#   inflating: content/Positive/15856_1.jpg
#   inflating: content/Positive/15857_1.jpg
#   inflating: content/Positive/15858_1.jpg
#   inflating: content/Positive/15859_1.jpg
#   inflating: content/Positive/15860_1.jpg
#   inflating: content/Positive/15861_1.jpg
#   inflating: content/Positive/15862_1.jpg
#   inflating: content/Positive/15863_1.jpg
#   inflating: content/Positive/15864_1.jpg
#   inflating: content/Positive/15865_1.jpg
#   inflating: content/Positive/15866_1.jpg
#   inflating: content/Positive/15867_1.jpg
#   inflating: content/Positive/15868_1.jpg
#   inflating: content/Positive/15869_1.jpg
#   inflating: content/Positive/15870_1.jpg
#   inflating: content/Positive/15871_1.jpg
#   inflating: content/Positive/15872_1.jpg
#   inflating: content/Positive/15873_1.jpg
#   inflating: content/Positive/15874_1.jpg
#   inflating: content/Positive/15875_1.jpg
#   inflating: content/Positive/15876_1.jpg
#   inflating: content/Positive/15877_1.jpg
#   inflating: content/Positive/15878_1.jpg
#   inflating: content/Positive/15879_1.jpg
#   inflating: content/Positive/15880_1.jpg
#   inflating: content/Positive/15881_1.jpg
#   inflating: content/Positive/15882_1.jpg
#   inflating: content/Positive/15883_1.jpg
#   inflating: content/Positive/15884_1.jpg
#   inflating: content/Positive/15885_1.jpg
#   inflating: content/Positive/15886_1.jpg
#   inflating: content/Positive/15887_1.jpg
#   inflating: content/Positive/15888_1.jpg
#   inflating: content/Positive/15889_1.jpg
#   inflating: content/Positive/15890_1.jpg
#   inflating: content/Positive/15891_1.jpg
#   inflating: content/Positive/15892_1.jpg
#   inflating: content/Positive/15893_1.jpg
#   inflating: content/Positive/15894_1.jpg
#   inflating: content/Positive/15895_1.jpg
#   inflating: content/Positive/15896_1.jpg
#   inflating: content/Positive/15897_1.jpg
#   inflating: content/Positive/15898_1.jpg
#   inflating: content/Positive/15899_1.jpg
#   inflating: content/Positive/15900_1.jpg
#   inflating: content/Positive/15901_1.jpg
#   inflating: content/Positive/15902_1.jpg
#   inflating: content/Positive/15903_1.jpg
#   inflating: content/Positive/15904_1.jpg
#   inflating: content/Positive/15905_1.jpg
#   inflating: content/Positive/15906_1.jpg
#   inflating: content/Positive/15907_1.jpg
#   inflating: content/Positive/15908_1.jpg
#   inflating: content/Positive/15909_1.jpg
#   inflating: content/Positive/15910_1.jpg
#   inflating: content/Positive/15911_1.jpg
#   inflating: content/Positive/15912_1.jpg
#   inflating: content/Positive/15913_1.jpg
#   inflating: content/Positive/15914_1.jpg
#   inflating: content/Positive/15915_1.jpg
#   inflating: content/Positive/15916_1.jpg
#   inflating: content/Positive/15917_1.jpg
#   inflating: content/Positive/15918_1.jpg
#   inflating: content/Positive/15919_1.jpg
#   inflating: content/Positive/15920_1.jpg
#   inflating: content/Positive/15921_1.jpg
#   inflating: content/Positive/15922_1.jpg
#   inflating: content/Positive/15923_1.jpg
#   inflating: content/Positive/15924_1.jpg
#   inflating: content/Positive/15925_1.jpg
#   inflating: content/Positive/15926_1.jpg
#   inflating: content/Positive/15927_1.jpg
#   inflating: content/Positive/15928_1.jpg
#   inflating: content/Positive/15929_1.jpg
#   inflating: content/Positive/15930_1.jpg
#   inflating: content/Positive/15931_1.jpg
#   inflating: content/Positive/15932_1.jpg
#   inflating: content/Positive/15933_1.jpg
#   inflating: content/Positive/15934_1.jpg
#   inflating: content/Positive/15935_1.jpg
#   inflating: content/Positive/15936_1.jpg
#   inflating: content/Positive/15937_1.jpg
#   inflating: content/Positive/15938_1.jpg
#   inflating: content/Positive/15939_1.jpg
#   inflating: content/Positive/15940_1.jpg
#   inflating: content/Positive/15941_1.jpg
#   inflating: content/Positive/15942_1.jpg
#   inflating: content/Positive/15943_1.jpg
#   inflating: content/Positive/15944_1.jpg
#   inflating: content/Positive/15945_1.jpg
#   inflating: content/Positive/15946_1.jpg
#   inflating: content/Positive/15947_1.jpg
#   inflating: content/Positive/15948_1.jpg
#   inflating: content/Positive/15949_1.jpg
#   inflating: content/Positive/15950_1.jpg
#   inflating: content/Positive/15951_1.jpg
#   inflating: content/Positive/15952_1.jpg
#   inflating: content/Positive/15953_1.jpg
#   inflating: content/Positive/15954_1.jpg
#   inflating: content/Positive/15955_1.jpg
#   inflating: content/Positive/15956_1.jpg
#   inflating: content/Positive/15957_1.jpg
#   inflating: content/Positive/15958_1.jpg
#   inflating: content/Positive/15959_1.jpg
#   inflating: content/Positive/15960_1.jpg
#   inflating: content/Positive/15961_1.jpg
#   inflating: content/Positive/15962_1.jpg
#   inflating: content/Positive/15963_1.jpg
#   inflating: content/Positive/15964_1.jpg
#   inflating: content/Positive/15965_1.jpg
#   inflating: content/Positive/15966_1.jpg
#   inflating: content/Positive/15967_1.jpg
#   inflating: content/Positive/15968_1.jpg
#   inflating: content/Positive/15969_1.jpg
#   inflating: content/Positive/15970_1.jpg
#   inflating: content/Positive/15971_1.jpg
#   inflating: content/Positive/15972_1.jpg
#   inflating: content/Positive/15973_1.jpg
#   inflating: content/Positive/15974_1.jpg
#   inflating: content/Positive/15975_1.jpg
#   inflating: content/Positive/15976_1.jpg
#   inflating: content/Positive/15977_1.jpg
#   inflating: content/Positive/15978_1.jpg
#   inflating: content/Positive/15979_1.jpg
#   inflating: content/Positive/15980_1.jpg
#   inflating: content/Positive/15981_1.jpg
#   inflating: content/Positive/15982_1.jpg
#   inflating: content/Positive/15983_1.jpg
#   inflating: content/Positive/15984_1.jpg
#   inflating: content/Positive/15985_1.jpg
#   inflating: content/Positive/15986_1.jpg
#   inflating: content/Positive/15987_1.jpg
#   inflating: content/Positive/15988_1.jpg
#   inflating: content/Positive/15989_1.jpg
#   inflating: content/Positive/15990_1.jpg
#   inflating: content/Positive/15991_1.jpg
#   inflating: content/Positive/15992_1.jpg
#   inflating: content/Positive/15993_1.jpg
#   inflating: content/Positive/15994_1.jpg
#   inflating: content/Positive/15995_1.jpg
#   inflating: content/Positive/15996_1.jpg
#   inflating: content/Positive/15997_1.jpg
#   inflating: content/Positive/15998_1.jpg
#   inflating: content/Positive/15999_1.jpg
#   inflating: content/Positive/16000_1.jpg
#   inflating: content/Positive/16001_1.jpg
#   inflating: content/Positive/16002_1.jpg
#   inflating: content/Positive/16003_1.jpg
#   inflating: content/Positive/16004_1.jpg
#   inflating: content/Positive/16005_1.jpg
#   inflating: content/Positive/16006_1.jpg
#   inflating: content/Positive/16007_1.jpg
#   inflating: content/Positive/16008_1.jpg
#   inflating: content/Positive/16009_1.jpg
#   inflating: content/Positive/16010_1.jpg
#   inflating: content/Positive/16011_1.jpg
#   inflating: content/Positive/16012_1.jpg
#   inflating: content/Positive/16013_1.jpg
#   inflating: content/Positive/16014_1.jpg
#   inflating: content/Positive/16015_1.jpg
#   inflating: content/Positive/16016_1.jpg
#   inflating: content/Positive/16017_1.jpg
#   inflating: content/Positive/16018_1.jpg
#   inflating: content/Positive/16019_1.jpg
#   inflating: content/Positive/16020_1.jpg
#   inflating: content/Positive/16021_1.jpg
#   inflating: content/Positive/16022_1.jpg
#   inflating: content/Positive/16023_1.jpg
#   inflating: content/Positive/16024_1.jpg
#   inflating: content/Positive/16025_1.jpg
#   inflating: content/Positive/16026_1.jpg
#   inflating: content/Positive/16027_1.jpg
#   inflating: content/Positive/16028_1.jpg
#   inflating: content/Positive/16029_1.jpg
#   inflating: content/Positive/16030_1.jpg
#   inflating: content/Positive/16031_1.jpg
#   inflating: content/Positive/16032_1.jpg
#   inflating: content/Positive/16033_1.jpg
#   inflating: content/Positive/16034_1.jpg
#   inflating: content/Positive/16035_1.jpg
#   inflating: content/Positive/16036_1.jpg
#   inflating: content/Positive/16037_1.jpg
#   inflating: content/Positive/16038_1.jpg
#   inflating: content/Positive/16039_1.jpg
#   inflating: content/Positive/16040_1.jpg
#   inflating: content/Positive/16041_1.jpg
#   inflating: content/Positive/16042_1.jpg
#   inflating: content/Positive/16043_1.jpg
#   inflating: content/Positive/16044_1.jpg
#   inflating: content/Positive/16045_1.jpg
#   inflating: content/Positive/16046_1.jpg
#   inflating: content/Positive/16047_1.jpg
#   inflating: content/Positive/16048_1.jpg
#   inflating: content/Positive/16049_1.jpg
#   inflating: content/Positive/16050_1.jpg
#   inflating: content/Positive/16051_1.jpg
#   inflating: content/Positive/16052_1.jpg
#   inflating: content/Positive/16053_1.jpg
#   inflating: content/Positive/16054_1.jpg
#   inflating: content/Positive/16055_1.jpg
#   inflating: content/Positive/16056_1.jpg
#   inflating: content/Positive/16057_1.jpg
#   inflating: content/Positive/16058_1.jpg
#   inflating: content/Positive/16059_1.jpg
#   inflating: content/Positive/16060_1.jpg
#   inflating: content/Positive/16061_1.jpg
#   inflating: content/Positive/16062_1.jpg
#   inflating: content/Positive/16063_1.jpg
#   inflating: content/Positive/16064_1.jpg
#   inflating: content/Positive/16065_1.jpg
#   inflating: content/Positive/16066_1.jpg
#   inflating: content/Positive/16067_1.jpg
#   inflating: content/Positive/16068_1.jpg
#   inflating: content/Positive/16069_1.jpg
#   inflating: content/Positive/16070_1.jpg
#   inflating: content/Positive/16071_1.jpg
#   inflating: content/Positive/16072_1.jpg
#   inflating: content/Positive/16073_1.jpg
#   inflating: content/Positive/16074_1.jpg
#   inflating: content/Positive/16075_1.jpg
#   inflating: content/Positive/16076_1.jpg
#   inflating: content/Positive/16077_1.jpg
#   inflating: content/Positive/16078_1.jpg
#   inflating: content/Positive/16079_1.jpg
#   inflating: content/Positive/16080_1.jpg
#   inflating: content/Positive/16081_1.jpg
#   inflating: content/Positive/16082_1.jpg
#   inflating: content/Positive/16083_1.jpg
#   inflating: content/Positive/16084_1.jpg
#   inflating: content/Positive/16085_1.jpg
#   inflating: content/Positive/16086_1.jpg
#   inflating: content/Positive/16087_1.jpg
#   inflating: content/Positive/16088_1.jpg
#   inflating: content/Positive/16089_1.jpg
# ...
#   inflating: content/Positive/19620.jpg
#   inflating: content/Positive/19621.jpg
#   inflating: content/Positive/19622.jpg
#   inflating: content/Positive/19623.jpg
#   inflating: content/Positive/19624.jpg
#   inflating: content/Positive/19625.jpg
#   inflating: content/Positive/19626.jpg
#   inflating: content/Positive/19627.jpg
#   inflating: content/Positive/19628.jpg
#   inflating: content/Positive/19629.jpg
#   inflating: content/Positive/19630.jpg
#   inflating: content/Positive/19631.jpg
#   inflating: content/Positive/19632.jpg
#   inflating: content/Positive/19633.jpg
#   inflating: content/Positive/19634.jpg
#   inflating: content/Positive/19635.jpg
#   inflating: content/Positive/19636.jpg
#   inflating: content/Positive/19637.jpg
#   inflating: content/Positive/19638.jpg
#   inflating: content/Positive/19639.jpg
#   inflating: content/Positive/19640.jpg
#   inflating: content/Positive/19641.jpg
#   inflating: content/Positive/19642.jpg
#   inflating: content/Positive/19643.jpg
#   inflating: content/Positive/19644.jpg
#   inflating: content/Positive/19645.jpg
#   inflating: content/Positive/19646.jpg
#   inflating: content/Positive/19647.jpg
#   inflating: content/Positive/19648.jpg
#   inflating: content/Positive/19649.jpg
#   inflating: content/Positive/19650.jpg
#   inflating: content/Positive/19651.jpg
#   inflating: content/Positive/19652.jpg
#   inflating: content/Positive/19653.jpg
#   inflating: content/Positive/19654.jpg
#   inflating: content/Positive/19655.jpg
#   inflating: content/Positive/19656.jpg
#   inflating: content/Positive/19657.jpg
#   inflating: content/Positive/19658.jpg
#   inflating: content/Positive/19659.jpg
#   inflating: content/Positive/19660.jpg
#   inflating: content/Positive/19661.jpg
#   inflating: content/Positive/19662.jpg
#   inflating: content/Positive/19663.jpg
#   inflating: content/Positive/19664.jpg
#   inflating: content/Positive/19665.jpg
#   inflating: content/Positive/19666.jpg
#   inflating: content/Positive/19667.jpg
#   inflating: content/Positive/19668.jpg
#   inflating: content/Positive/19669.jpg
#   inflating: content/Positive/19670.jpg
#   inflating: content/Positive/19671.jpg
#   inflating: content/Positive/19672.jpg
#   inflating: content/Positive/19673.jpg
#   inflating: content/Positive/19674.jpg
#   inflating: content/Positive/19675.jpg
#   inflating: content/Positive/19676.jpg
#   inflating: content/Positive/19677.jpg
#   inflating: content/Positive/19678.jpg
#   inflating: content/Positive/19679.jpg
#   inflating: content/Positive/19680.jpg
#   inflating: content/Positive/19681.jpg
#   inflating: content/Positive/19682.jpg
#   inflating: content/Positive/19683.jpg
#   inflating: content/Positive/19684.jpg
#   inflating: content/Positive/19685.jpg
#   inflating: content/Positive/19686.jpg
#   inflating: content/Positive/19687.jpg
#   inflating: content/Positive/19688.jpg
#   inflating: content/Positive/19689.jpg
#   inflating: content/Positive/19690.jpg
#   inflating: content/Positive/19691.jpg
#   inflating: content/Positive/19692.jpg
#   inflating: content/Positive/19693.jpg
#   inflating: content/Positive/19694.jpg
#   inflating: content/Positive/19695.jpg
#   inflating: content/Positive/19696.jpg
#   inflating: content/Positive/19697.jpg
#   inflating: content/Positive/19698.jpg
#   inflating: content/Positive/19699.jpg
#   inflating: content/Positive/19700.jpg
#   inflating: content/Positive/19701.jpg
#   inflating: content/Positive/19702.jpg
#   inflating: content/Positive/19703.jpg
#   inflating: content/Positive/19704.jpg
#   inflating: content/Positive/19705.jpg
#   inflating: content/Positive/19706.jpg
#   inflating: content/Positive/19707.jpg
#   inflating: content/Positive/19708.jpg
#   inflating: content/Positive/19709.jpg
#   inflating: content/Positive/19710.jpg
#   inflating: content/Positive/19711.jpg
#   inflating: content/Positive/19712.jpg
#   inflating: content/Positive/19713.jpg
#   inflating: content/Positive/19714.jpg
#   inflating: content/Positive/19715.jpg
#   inflating: content/Positive/19716.jpg
#   inflating: content/Positive/19717.jpg
#   inflating: content/Positive/19718.jpg
#   inflating: content/Positive/19719.jpg
#   inflating: content/Positive/19720.jpg
#   inflating: content/Positive/19721.jpg
#   inflating: content/Positive/19722.jpg
#   inflating: content/Positive/19723.jpg
#   inflating: content/Positive/19724.jpg
#   inflating: content/Positive/19725.jpg
#   inflating: content/Positive/19726.jpg
#   inflating: content/Positive/19727.jpg
#   inflating: content/Positive/19728.jpg
#   inflating: content/Positive/19729.jpg
#   inflating: content/Positive/19730.jpg
#   inflating: content/Positive/19731.jpg
#   inflating: content/Positive/19732.jpg
#   inflating: content/Positive/19733.jpg
#   inflating: content/Positive/19734.jpg
#   inflating: content/Positive/19735.jpg
#   inflating: content/Positive/19736.jpg
#   inflating: content/Positive/19737.jpg
#   inflating: content/Positive/19738.jpg
#   inflating: content/Positive/19739.jpg
#   inflating: content/Positive/19740.jpg
#   inflating: content/Positive/19741.jpg
#   inflating: content/Positive/19742.jpg
#   inflating: content/Positive/19743.jpg
#   inflating: content/Positive/19744.jpg
#   inflating: content/Positive/19745.jpg
#   inflating: content/Positive/19746.jpg
#   inflating: content/Positive/19747.jpg
#   inflating: content/Positive/19748.jpg
#   inflating: content/Positive/19749.jpg
#   inflating: content/Positive/19750.jpg
#   inflating: content/Positive/19751.jpg
#   inflating: content/Positive/19752.jpg
#   inflating: content/Positive/19753.jpg
#   inflating: content/Positive/19754.jpg
#   inflating: content/Positive/19755.jpg
#   inflating: content/Positive/19756.jpg
#   inflating: content/Positive/19757.jpg
#   inflating: content/Positive/19758.jpg
#   inflating: content/Positive/19759.jpg
#   inflating: content/Positive/19760.jpg
#   inflating: content/Positive/19761.jpg
#   inflating: content/Positive/19762.jpg
#   inflating: content/Positive/19763.jpg
#   inflating: content/Positive/19764.jpg
#   inflating: content/Positive/19765.jpg
#   inflating: content/Positive/19766.jpg
#   inflating: content/Positive/19767.jpg
#   inflating: content/Positive/19768.jpg
#   inflating: content/Positive/19769.jpg
#   inflating: content/Positive/19770.jpg
#   inflating: content/Positive/19771.jpg
#   inflating: content/Positive/19772.jpg
#   inflating: content/Positive/19773.jpg
#   inflating: content/Positive/19774.jpg
#   inflating: content/Positive/19775.jpg
#   inflating: content/Positive/19776.jpg
#   inflating: content/Positive/19777.jpg
#   inflating: content/Positive/19778.jpg
#   inflating: content/Positive/19779.jpg
#   inflating: content/Positive/19780.jpg
#   inflating: content/Positive/19781.jpg
#   inflating: content/Positive/19782.jpg
#   inflating: content/Positive/19783.jpg
#   inflating: content/Positive/19784.jpg
#   inflating: content/Positive/19785.jpg
#   inflating: content/Positive/19786.jpg
#   inflating: content/Positive/19787.jpg
#   inflating: content/Positive/19788.jpg
#   inflating: content/Positive/19789.jpg
#   inflating: content/Positive/19790.jpg
#   inflating: content/Positive/19791.jpg
#   inflating: content/Positive/19792.jpg
#   inflating: content/Positive/19793.jpg
#   inflating: content/Positive/19794.jpg
#   inflating: content/Positive/19795.jpg
#   inflating: content/Positive/19796.jpg
#   inflating: content/Positive/19797.jpg
#   inflating: content/Positive/19798.jpg
#   inflating: content/Positive/19799.jpg
#   inflating: content/Positive/19800.jpg
#   inflating: content/Positive/19801.jpg
#   inflating: content/Positive/19802.jpg
#   inflating: content/Positive/19803.jpg
#   inflating: content/Positive/19804.jpg
#   inflating: content/Positive/19805.jpg
#   inflating: content/Positive/19806.jpg
#   inflating: content/Positive/19807.jpg
#   inflating: content/Positive/19808.jpg
#   inflating: content/Positive/19809.jpg
#   inflating: content/Positive/19810.jpg
#   inflating: content/Positive/19811.jpg
#   inflating: content/Positive/19812.jpg
#   inflating: content/Positive/19813.jpg
#   inflating: content/Positive/19814.jpg
#   inflating: content/Positive/19815.jpg
#   inflating: content/Positive/19816.jpg
#   inflating: content/Positive/19817.jpg
#   inflating: content/Positive/19818.jpg
#   inflating: content/Positive/19819.jpg
#   inflating: content/Positive/19820.jpg
#   inflating: content/Positive/19821.jpg
#   inflating: content/Positive/19822.jpg
#   inflating: content/Positive/19823.jpg
#   inflating: content/Positive/19824.jpg
#   inflating: content/Positive/19825.jpg
#   inflating: content/Positive/19826.jpg
#   inflating: content/Positive/19827.jpg
#   inflating: content/Positive/19828.jpg
#   inflating: content/Positive/19829.jpg
#   inflating: content/Positive/19830.jpg
#   inflating: content/Positive/19831.jpg
#   inflating: content/Positive/19832.jpg
#   inflating: content/Positive/19833.jpg
#   inflating: content/Positive/19834.jpg
#   inflating: content/Positive/19835.jpg
#   inflating: content/Positive/19836.jpg
#   inflating: content/Positive/19837.jpg
#   inflating: content/Positive/19838.jpg
#   inflating: content/Positive/19839.jpg
#   inflating: content/Positive/19840.jpg
#   inflating: content/Positive/19841.jpg
#   inflating: content/Positive/19842.jpg
#   inflating: content/Positive/19843.jpg
#   inflating: content/Positive/19844.jpg
#   inflating: content/Positive/19845.jpg
#   inflating: content/Positive/19846.jpg
#   inflating: content/Positive/19847.jpg
#   inflating: content/Positive/19848.jpg
#   inflating: content/Positive/19849.jpg
#   inflating: content/Positive/19850.jpg
#   inflating: content/Positive/19851.jpg
#   inflating: content/Positive/19852.jpg
#   inflating: content/Positive/19853.jpg
#   inflating: content/Positive/19854.jpg
#   inflating: content/Positive/19855.jpg
#   inflating: content/Positive/19856.jpg
#   inflating: content/Positive/19857.jpg
#   inflating: content/Positive/19858.jpg
#   inflating: content/Positive/19859.jpg
#   inflating: content/Positive/19860.jpg
#   inflating: content/Positive/19861.jpg
#   inflating: content/Positive/19862.jpg
#   inflating: content/Positive/19863.jpg
#   inflating: content/Positive/19864.jpg
#   inflating: content/Positive/19865.jpg
#   inflating: content/Positive/19866.jpg
#   inflating: content/Positive/19867.jpg
#   inflating: content/Positive/19868.jpg
#   inflating: content/Positive/19869.jpg
#   inflating: content/Positive/19870.jpg
#   inflating: content/Positive/19871.jpg
#   inflating: content/Positive/19872.jpg
#   inflating: content/Positive/19873.jpg
#   inflating: content/Positive/19874.jpg
#   inflating: content/Positive/19875.jpg
#   inflating: content/Positive/19876.jpg
#   inflating: content/Positive/19877.jpg
#   inflating: content/Positive/19878.jpg
#   inflating: content/Positive/19879.jpg
#   inflating: content/Positive/19880.jpg
#   inflating: content/Positive/19881.jpg
#   inflating: content/Positive/19882.jpg
#   inflating: content/Positive/19883.jpg
#   inflating: content/Positive/19884.jpg
#   inflating: content/Positive/19885.jpg
#   inflating: content/Positive/19886.jpg
#   inflating: content/Positive/19887.jpg
#   inflating: content/Positive/19888.jpg
#   inflating: content/Positive/19889.jpg
#   inflating: content/Positive/19890.jpg
#   inflating: content/Positive/19891.jpg
#   inflating: content/Positive/19892.jpg
#   inflating: content/Positive/19893.jpg
#   inflating: content/Positive/19894.jpg
#   inflating: content/Positive/19895.jpg
#   inflating: content/Positive/19896.jpg
#   inflating: content/Positive/19897.jpg
#   inflating: content/Positive/19898.jpg
#   inflating: content/Positive/19899.jpg
#   inflating: content/Positive/19900.jpg
#   inflating: content/Positive/19901.jpg
#   inflating: content/Positive/19902.jpg
#   inflating: content/Positive/19903.jpg
#   inflating: content/Positive/19904.jpg
#   inflating: content/Positive/19905.jpg
#   inflating: content/Positive/19906.jpg
#   inflating: content/Positive/19907.jpg
#   inflating: content/Positive/19908.jpg
#   inflating: content/Positive/19909.jpg
#   inflating: content/Positive/19910.jpg
#   inflating: content/Positive/19911.jpg
#   inflating: content/Positive/19912.jpg
#   inflating: content/Positive/19913.jpg
#   inflating: content/Positive/19914.jpg
#   inflating: content/Positive/19915.jpg
#   inflating: content/Positive/19916.jpg
#   inflating: content/Positive/19917.jpg
#   inflating: content/Positive/19918.jpg
#   inflating: content/Positive/19919.jpg
#   inflating: content/Positive/19920.jpg
#   inflating: content/Positive/19921.jpg
#   inflating: content/Positive/19922.jpg
#   inflating: content/Positive/19923.jpg
#   inflating: content/Positive/19924.jpg
#   inflating: content/Positive/19925.jpg
#   inflating: content/Positive/19926.jpg
#   inflating: content/Positive/19927.jpg
#   inflating: content/Positive/19928.jpg
#   inflating: content/Positive/19929.jpg
#   inflating: content/Positive/19930.jpg
#   inflating: content/Positive/19931.jpg
#   inflating: content/Positive/19932.jpg
#   inflating: content/Positive/19933.jpg
#   inflating: content/Positive/19934.jpg
#   inflating: content/Positive/19935.jpg
#   inflating: content/Positive/19936.jpg
#   inflating: content/Positive/19937.jpg
#   inflating: content/Positive/19938.jpg
#   inflating: content/Positive/19939.jpg
#   inflating: content/Positive/19940.jpg
#   inflating: content/Positive/19941.jpg
#   inflating: content/Positive/19942.jpg
#   inflating: content/Positive/19943.jpg
#   inflating: content/Positive/19944.jpg
#   inflating: content/Positive/19945.jpg
#   inflating: content/Positive/19946.jpg
#   inflating: content/Positive/19947.jpg
#   inflating: content/Positive/19948.jpg
#   inflating: content/Positive/19949.jpg
#   inflating: content/Positive/19950.jpg
#   inflating: content/Positive/19951.jpg
#   inflating: content/Positive/19952.jpg
#   inflating: content/Positive/19953.jpg
#   inflating: content/Positive/19954.jpg
#   inflating: content/Positive/19955.jpg
#   inflating: content/Positive/19956.jpg
#   inflating: content/Positive/19957.jpg
#   inflating: content/Positive/19958.jpg
#   inflating: content/Positive/19959.jpg
#   inflating: content/Positive/19960.jpg
#   inflating: content/Positive/19961.jpg
#   inflating: content/Positive/19962.jpg
#   inflating: content/Positive/19963.jpg
#   inflating: content/Positive/19964.jpg
#   inflating: content/Positive/19965.jpg
#   inflating: content/Positive/19966.jpg
#   inflating: content/Positive/19967.jpg
#   inflating: content/Positive/19968.jpg
#   inflating: content/Positive/19969.jpg
#   inflating: content/Positive/19970.jpg
#   inflating: content/Positive/19971.jpg
#   inflating: content/Positive/19972.jpg
#   inflating: content/Positive/19973.jpg
#   inflating: content/Positive/19974.jpg
#   inflating: content/Positive/19975.jpg
#   inflating: content/Positive/19976.jpg
#   inflating: content/Positive/19977.jpg
#   inflating: content/Positive/19978.jpg
#   inflating: content/Positive/19979.jpg
#   inflating: content/Positive/19980.jpg
#   inflating: content/Positive/19981.jpg
#   inflating: content/Positive/19982.jpg
#   inflating: content/Positive/19983.jpg
#   inflating: content/Positive/19984.jpg
#   inflating: content/Positive/19985.jpg
#   inflating: content/Positive/19986.jpg
#   inflating: content/Positive/19987.jpg
#   inflating: content/Positive/19988.jpg
#   inflating: content/Positive/19989.jpg
#   inflating: content/Positive/19990.jpg
#   inflating: content/Positive/19991.jpg
#   inflating: content/Positive/19992.jpg
#   inflating: content/Positive/19993.jpg
#   inflating: content/Positive/19994.jpg
#   inflating: content/Positive/19995.jpg
#   inflating: content/Positive/19996.jpg
#   inflating: content/Positive/19997.jpg
#   inflating: content/Positive/19998.jpg
#   inflating: content/Positive/19999.jpg
#   inflating: content/Positive/20000.jpg

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import os

# %% [markdown]
# #### set the data path

# %%
#this tells the python that the main dataset folder is named content
DATA_PATH="content"

# %%
def understanding_data(data_path=DATA_PATH):
    """
    this function will help us understand the data and answer simple questions like
    - how many images are there?
    - what do they look like?
    - are the classes balanced or not?
    """
    # define paths to the two dataset folders: cracked (Positive) and non-cracked (Negative)
    positive_path = Path(data_path) / "Positive"
    negative_path = Path(data_path) / "Negative"

    # count how many images (.jpg) are in each folder
    positive_images_count = len(list(positive_path.glob("*.jpg"))) if positive_path.exists() else 0
    negative_images_count = len(list(negative_path.glob("*.jpg"))) if negative_path.exists() else 0

    print("=" * 50)
    print("Dataset Overview")
    print("=" * 50)
    print(f"count of positive samples (images with cracks): {positive_images_count}")
    print(f"count of negative samples (images with no cracks): {negative_images_count}")
    print(f"total count of images: {positive_images_count + negative_images_count}")
    print(f"ratio of positive to negative images: {positive_images_count / negative_images_count:.2f}")
    print("=" * 50)

    return positive_path, negative_path

# %%
positive_path, negative_path = understanding_data()
# Out:
# ==================================================
# Dataset Overview
# ==================================================
# count of positive samples (images with cracks): 20000
# count of negative samples (images with no cracks): 20000
# total count of images: 40000
# ratio of positive to negative images: 1.00
# ==================================================

# %% [markdown]
# #### now lets visualize the sample images to know what the model sees

# %%
def visualize_sample_images(data_path=DATA_PATH ,n_samples=5):

    """
    we will display samples images from both classes
    this will help us understand the image quality , how the images differ, cracked or not cracked images
    and if it needs any preprocessing
    """

    fig, axes = plt.subplots(2, n_samples, figsize=(15, 6))  # 2 rows, n_samples per row
    fig.suptitle(
        "Sample Images: Top Row= Positive(Cracked), Bottom Row =Negative(no cracks)",
        fontsize=14,
        fontweight="bold"
    )  # subtitle for the whole figure

    # find all the jpg images in both +ve and -ve folder and list the first n_samples
    positive_images = list(positive_path.glob("*.jpg"))[:n_samples]
    negative_images = list(negative_path.glob("*.jpg"))[:n_samples]

    # loop over positive images (top row)
    for i, img_path in enumerate(positive_images):
        img = plt.imread(img_path)
        axes[0, i].imshow(img)
        axes[0, i].axis("off")
        axes[0, i].set_title(f"crack image {i+1}", color="red")

    # loop over negative images (bottom row)
    for i, img_path in enumerate(negative_images):
        img = plt.imread(img_path)
        axes[1, i].imshow(img)
        axes[1, i].axis("off")
        axes[1, i].set_title(f"normal(no cracks) image {i+1}", color="red")

    plt.tight_layout()
    plt.show()

# %%
visualize_sample_images()

# %% [markdown]
# #### next, we need to load the data

# %%
"""
there are around 40,000 images ,loading all at onces will fry my ram ,
so we will load the images in batches of 32 images at a time
and also reduce the image size for faster processing
"""

#Configure before loading
img_size=224
batch_size=32
validation_split=0.2

# now we need to created the datasets

def create_dataset(data_path=DATA_PATH,img_size=img_size,batch_size=batch_size,val_split= validation_split):
  """
  lets understand how this will work
  -first  image_dataset_from_directory will automatically
   a)load the images from postive and negative folder thats inside the root content folder
   b) assign label (0=negative and 1 = postive)
   c) resizez the images to img_size
   d)create batches that equal to batch_size
   e) split the data into train(80%) and validation set(0.2 ie 20%)
   f) then normalize the pixels from 0-255 to 0-1
  """

  ## we will use tensorflow dataset generators to create training and validation dataset

  train_dataset= tf.keras.preprocessing.image_dataset_from_directory(
      data_path,
      validation_split=val_split,
      subset="training",
      seed=123,
      image_size=(img_size,img_size),
      batch_size=batch_size,
      label_mode="binary",
      color_mode="rgb"
  )

  validation_dataset= tf.keras.preprocessing.image_dataset_from_directory(
      data_path,
      validation_split=val_split,
      subset="validation",
      seed=123,
      image_size=(img_size,img_size), #tensorFlow to resize every image to 128×128 pixels.
      batch_size=batch_size,
      label_mode="binary",
      color_mode="rgb"
  )

  # #normalize the pixels value
  # def normalize_images(image,label):
  #   image =tf.cast(image,tf.float32) /255.0
  #   return image,label

  # train_dataset=train_dataset.map(normalize_images)
  # validation_dataset=validation_dataset.map(normalize_images)

  # for performance optimization we will prefetch, ie
  #load the next batch while training the current batch

  train_dataset= train_dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
  validation_dataset= validation_dataset.prefetch(buffer_size=tf.data.AUTOTUNE)

  return train_dataset,validation_dataset

# %%
train_dataset, validation_dataset= create_dataset()
# Out:
# Found 40000 files belonging to 2 classes.
# Using 32000 files for training.
# Found 40000 files belonging to 2 classes.
# Using 8000 files for validation.

# %% [markdown]
# #### we will create a baseline model and then improve the performance

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dropout, Dense

# %%
from tensorflow.keras.models import Model
def baseline_cnn_model(img_size=img_size):
  """lets understand our baseline cnn architecture

    input(224*224)
    ↓
    convo laeyer 1 with 32 filters ->goal detect edges and lines
    ↓
    maxpool(pool_size= 2,2)
    ↓
    convo layer 2 with 64 filters -> goal detect more complex features
    ↓
    maxpool(pool_size= 2,2)
    ↓
    convo layer 3 with 64 filters->complex pattern
    ↓
    flattern to 1d
    ↓
    dense layer  with 64 neurons ,activation="relu"
    ↓
    output with sigmoid
  """

  inputs = Input(shape=(img_size,img_size,3))

  #first convo layer
  x = Conv2D(32,(3,3),activation="relu",padding="same")(inputs)
  x = MaxPooling2D(pool_size=(2,2))(x)

  #second convo layer
  x = Conv2D(64,(3,3),activation="relu",padding="same")(x)
  x = MaxPooling2D(pool_size=(2,2))(x)

  #third convo layer
  x = Conv2D(64,(3,3),activation="relu",padding="same")(x)
  x = MaxPooling2D(pool_size=(2,2))(x)

  #flatten
  x = Flatten()(x)
  #adding a dropout to prevent overfitting
  x = Dropout(0.5)(x)

  #dense layer
  x = Dense(64,activation="relu")(x)

  #output layer
  outputs = Dense(1,activation="sigmoid")(x)

  model = Model(inputs, outputs, name="baseline_cnn")

  return model

# %%
our_model = baseline_cnn_model()

# %% [markdown]
# #### lets show the model structure and summary

# %%
print("\n"+"="*50)
print("our model architecture")
print("="*50)
our_model.summary()
# Out:
# ==================================================
# our model architecture
# ==================================================
# Model: "baseline_cnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_8 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 56, 56, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 28, 28, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 50176)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 50176)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 64)             │     3,211,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,267,713 (12.47 MB)
#  Trainable params: 3,267,713 (12.47 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### now its time to compile the model

# %%
def compile_model(model):
  """
  we will now configure how the model should learn,
  we will configure the optimizer , loss and metrics
  """

  model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

  return model

# %%
our_model=compile_model(our_model)

# %% [markdown]
# #### after compiling, its time to train the model

# %%
def train_model(model, train_dataset, validation_dataset, epochs=10):
    """
    we will train the model for 10 epochs,
    each epoch the model will see all the training images once
    and checks the performance on unseen data

    we will use callbacks to apply EarlyStopping to stop training if the model stops improving
    and use ReduceLROnPlateau to reduce learning rate if stuck
    """

    callbacks = [
        tf.keras.callbacks.EarlyStopping(
            monitor="val_loss",
            patience=5, # Stop if no improvement for 5 epochs
            restore_best_weights=True
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor="val_loss",
            factor=0.2, # Reduce learning rate by 0.2x
            patience=3
        )
    ]

    history = model.fit(
        train_dataset,
        validation_data=validation_dataset,
        epochs=epochs,
        callbacks=callbacks
    )

    return history

# %%
history=train_model(our_model,train_dataset,validation_dataset,epochs=10)
# Out:
# Epoch 1/10
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 57s 53ms/step - accuracy: 0.5060 - loss: 9.2359 - val_accuracy: 0.5100 - val_loss: 0.6931 - learning_rate: 0.0010
# Epoch 2/10
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 53s 53ms/step - accuracy: 0.5041 - loss: 0.6931 - val_accuracy: 0.5100 - val_loss: 0.6931 - learning_rate: 0.0010
# Epoch 3/10
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 51s 51ms/step - accuracy: 0.5027 - loss: 0.6931 - val_accuracy: 0.5100 - val_loss: 0.6931 - learning_rate: 0.0010
# Epoch 4/10
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 51s 51ms/step - accuracy: 0.5014 - loss: 0.6931 - val_accuracy: 0.5100 - val_loss: 0.6931 - learning_rate: 0.0010
# Epoch 5/10
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 51s 51ms/step - accuracy: 0.4938 - loss: 0.6932 - val_accuracy: 0.5100 - val_loss: 0.6931 - learning_rate: 2.0000e-04
# Epoch 6/10
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 52s 52ms/step - accuracy: 0.5038 - loss: 0.6931 - val_accuracy: 0.4900 - val_loss: 0.6932 - learning_rate: 2.0000e-04
# Epoch 7/10
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 53s 53ms/step - accuracy: 0.5060 - loss: 0.6931 - val_accuracy: 0.4900 - val_loss: 0.6932 - learning_rate: 2.0000e-04
# Epoch 8/10
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 52s 51ms/step - accuracy: 0.5062 - loss: 0.6931 - val_accuracy: 0.4900 - val_loss: 0.6932 - learning_rate: 4.0000e-05
# Epoch 9/10
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 51s 51ms/step - accuracy: 0.5058 - loss: 0.6931 - val_accuracy: 0.4900 - val_loss: 0.6932 - learning_rate: 4.0000e-05

# %%
def plot_training_history(history):
    """
    now we visualize how model improved over time
    - loss should decrease
    - accuracy should increase
    - train and validation should be close (no overfitting)
    """

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))


    ax1.plot(history.history['accuracy'], label='train accuracy', linewidth=2)
    ax1.plot(history.history['val_accuracy'], label='validation Accuracy', linewidth=2)
    ax1.set_title('model accuracy Over time', fontsize=14, fontweight='bold')
    ax1.set_xlabel('epoch')
    ax1.set_ylabel('accuracy')
    ax1.legend()
    ax1.grid(True, alpha=0.3)


    ax2.plot(history.history['loss'], label='train loss', linewidth=2)
    ax2.plot(history.history['val_loss'], label='validation Loss', linewidth=2)
    ax2.set_title('model loss over time', fontsize=14, fontweight='bold')
    ax2.set_xlabel('epoch')
    ax2.set_ylabel('loss')
    ax2.legend()
    ax2.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

# %%
plot_training_history(history)

# %%
our_model.evaluate(validation_dataset)
# Out:
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - accuracy: 0.5075 - loss: 0.6931
# [0.693080484867096, 0.5099999904632568]

# %% [markdown]
# #### we completed our baseline model, now we can start working on working using Pretrained modele

# %% [markdown]
# ### we will be using EfficientNet0 pretrained model

# %% [markdown]
# ##### first the step is to augument the data, lets create a function that does that

# %%
def create_data_augmentation():
  """
  data aug means artificially increasing the dataset by making small random
  changes to the existing images ,to generalize better and avoid overfitting.
  we will use the exisiting images we have and apply augmentation
  i.e apply this random changes to the images:
  random rotation around 20 degree
  random zoom around 20
  random translation 15%
  random horizontal flip
  random contrast around 20%

  each augmentation simulates a real world distortion,
  we want to augument just enough to make the model robust,
  but not so much that the image loses its meaning.
  we will will use the safe range of these values.
  """

  data_augmentation= keras.Sequential([
      layers.RandomRotation(0.2),
      layers.RandomTranslation(0.15,0.15),
      layers.RandomZoom(0.2),
      layers.RandomFlip("horizontal"),
      layers.RandomContrast(0.2),
  ],name="data_augmentation")

  return data_augmentation


augmentation= create_data_augmentation()
print("data aug pipeline created")
# Out:
# data aug pipeline created

# %% [markdown]
# #### we will now visualize how  augumentation makes the training data diverse.

# %%
def show_augmentation_examples(image, n_examples=9):

    plt.figure(figsize=(15, 10))
    # first lets plot the original image.
    plt.subplot(3, 4, 1)
    plt.imshow(image)
    plt.title('original image', fontweight="bold", fontsize=14)
    plt.axis('off')

    # now we plot the augmented versions of the image
    for i in range(n_examples):
        # apply the augmentation pipeline to the image
        # tf.expand_dims(image, 0) adds a batch dimension because Keras layers expect input in the format (batch, height, width, channels)
        # training=True ensures that the augmentations (rotation, flip, zoom, etc.) are applied and not skipped
        augmented = augmentation(tf.expand_dims(image, 0), training=True)
        plt.subplot(3, 4, i + 2)
         # check if pixel values are in range [0, 255] or [0, 1] for proper visualization
        plt.imshow(augmented[0] / 255.0 if augmented[0].numpy().max() > 1 else augmented[0])
        plt.title(f"Augmented {i+1}", fontsize=10)
        plt.axis('off')
    plt.tight_layout()



# from tensorflow.keras.preprocessing import image
# import tensorflow as tf

# #### this block of code is just to show how the augmentation works
# sample_image_path = "./sample.jpeg"
# img = image.load_img(sample_image_path, target_size=(224, 224))
# img_array = image.img_to_array(img)
# img_array = img_array / 255.0

# show_augmentation_examples(img_array)

# %% [markdown]
# #### create a function for creating the  efficient base model

# %%
from tensorflow.keras.applications import EfficientNetB0

#### create EfficientNetB0 base model
def create_efficientnet_basemodel(img_size=224, trainable=False):
    """
    first we load the EfficientNetB0 pretrained model.

    we are using B0 because it is the baseline EfficientNet model with ~5.3 million parameters.
    models B1-B7 are larger and will take more time to train and fine-tune.

    parameters explanation:
    - img_size: 224 x 224, the input image size expected by the model
    - trainable: False means we freeze the pretrained weights and do not update them during training.
                 we use the weights pretrained on ImageNet dataset
    - weights: 'imagenet' to use pretrained weights
    - include_top: False to remove the original classification head because we will add our own dense layer
    basically   we only get convolutional base section.

    """

    efficientnet_base = EfficientNetB0(
        include_top=False,
        weights="imagenet",
        input_shape=(img_size, img_size, 3),  # 3 channels for RGB
    )

    # set whether the base model is trainable
    efficientnet_base.trainable = trainable

    # summary print
    print(f"\n{'='*60}")
    print("EfficientNetB0 base model loaded")
    print(f"{'='*60}")
    print(f"Total layers: {len(efficientnet_base.layers)}")
    print(f"Trainable: {trainable}")
    print(f"Parameters: {efficientnet_base.count_params()}")
    print(f"Input size: {img_size}x{img_size}x3")

    return efficientnet_base

#all this does is, loads the pretrained EfficientNetB0 model and returns only the convolutional base.
#we can add our own Dense layers for the specific task.

# %% [markdown]
# #### now we will build the complete model ,combining the convo base we get from above with our own dense layers

# %%
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
def build_model(img_size=224):
    """
    we will use the transfer learning architecture:

    Input(224x224x3)
    ↓
    Augmentation (training only)
    ↓
    EfficientNet Preprocessing (FIXED: normalize to [-1, 1])
    ↓
    EfficientNetB0 convolutional base
    ↓
    GlobalAveragePooling2D (replaces Flatten)
    ↓
    BatchNormalization
    ↓
    Dropout
    ↓
    Dense layer
    ↓
    BatchNormalization
    ↓
    Dropout
    ↓
    Dense output (Sigmoid)
    """

    base_model = create_efficientnet_basemodel(img_size, trainable=False)
    inputs=Input(shape=(img_size,img_size,3))
    x=augmentation(inputs)
    print(f"Shape after augmentation: {x.shape}")
    x=keras.applications.efficientnet.preprocess_input(x) #use efficientNet's preprocessing function
    x=base_model(x,training=False)

    x=layers.GlobalAveragePooling2D()(x)
    x=layers.BatchNormalization()(x)
    x=layers.Dropout(0.5)(x)
    x=layers.Dense(256,activation="relu",kernel_regularizer=l2(0.001))(x)
    x=layers.BatchNormalization()(x)
    x=layers.Dropout(0.3)(x)

    outputs= layers.Dense(1,activation="sigmoid")(x)

    model=Model(inputs,outputs,name="final_model")

    return model

#create the final model
complete_model = build_model()

print("\n" + "="*60)
print("efficientnet transfer learning model")
print("="*60)
complete_model.summary()
# Out:
# ============================================================
# EfficientNetB0 base model loaded
# ============================================================
# Total layers: 238
# Trainable: False
# Parameters: 4049571
# Input size: 224x224x3
# Shape after augmentation: (None, 224, 224, 3)
#
# ============================================================
# efficientnet transfer learning model
# ============================================================
# Model: "final_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_10 (InputLayer)     │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ data_augmentation (Sequential)  │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_2      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 1280)           │         5,120 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,383,908 (16.72 MB)
#  Trainable params: 331,265 (1.26 MB)
#  Non-trainable params: 4,052,643 (15.46 MB)

# %% [markdown]
# #### we will now create a function that takes the model and compiles it

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow import keras

def compile_model(model):
    model.compile(
        optimizer=Adam(learning_rate=0.0001),
        loss="binary_crossentropy",
        metrics=[
            "accuracy",
            keras.metrics.Precision(name="precision"),
            keras.metrics.Recall(name="recall"),
            keras.metrics.AUC(name="auc")
        ]
    )


    print("\n model compiled with optimized settings")
    print("\nmetrics explained:")
    print("  - accuracy: overall correctness")
    print("  - precision: correct crack predictions")
    print("  - recall: detected real cracks")
    print("  - auc: overall model quality (higher is better)")

    return model

# compile the model by calling the func
complete_model = compile_model(complete_model)
# Out:
#  model compiled with optimized settings
#
# metrics explained:
#   - accuracy: overall correctness
#   - precision: correct crack predictions
#   - recall: detected real cracks
#   - auc: overall model quality (higher is better)

# %% [markdown]
# #### after compilation, its time to train the model

# %%
#### we will create the function to train the model

# %%
def train_eff_model(model,train_dataset,validation_dataset,epochs=20):
  """
  we will keep the efficientNet weights frozen(use pretrained knowledge)
  and train only the classificiation head (the ann section)to learn the crack patterns
  and we will use callbacks to make the training smarter and more stable

  in callbacks,
  we  will use early stopping-> ie stop if val_auc doesnt improve for 5 epochs
  we will use ReduceLROnPlateau →ie halve learning rate if stuck for 3 epochs
 and ModelCheckpoint → ie save the best model automatically
  """

  callbacks=[
      # stop early if no improvement
      keras.callbacks.EarlyStopping(
          monitor="val_auc",
          patience=5,
          restore_best_weights=True,
          mode="max", #indicates we want to maximize the monitored metric (val_auc). If using accuracy, also "max". For loss, use "min".
          verbose=1
      ),
      #reduce the learning rate when stuck
      keras.callbacks.ReduceLROnPlateau(
          monitor="val_loss",
          factor=0.5,
          patience=3,
          min_lr=1e-7, #lr cant go low than this
          verbose=1
      ),
      #save the best model
    keras.callbacks.ModelCheckpoint(
    'models/best_model.keras',  # New Keras format
    monitor="val_auc",
    save_best_only=True,
    mode='max',
    verbose=1
)
  ]

  print("\n" + "="*60)
  print("training classification head(the ann part)")
  print("\n" + "="*60)
  print("base model frozen keeping imagenet knowledge")
  print("training classfication layers only")
  print("="*60 + "\n")

  history= model.fit(train_dataset, validation_data=validation_dataset, epochs=epochs, verbose=1,callbacks=callbacks)

  print("\n" + "="*60)
  print("✓ PHASE 1 COMPLETE")
  print("="*60)

  return history

# %%
history=train_eff_model(complete_model,train_dataset,validation_dataset,epochs=20)
# Out:
# ============================================================
# training classification head(the ann part)
#
# ============================================================
# base model frozen keeping imagenet knowledge
# training classfication layers only
# ============================================================
#
# Epoch 1/20
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9641 - auc: 0.9905 - loss: 0.4878 - precision: 0.9733 - recall: 0.9544
# Epoch 1: val_auc improved from -inf to 0.99972, saving model to models/best_model.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 120s 108ms/step - accuracy: 0.9641 - auc: 0.9905 - loss: 0.4877 - precision: 0.9733 - recall: 0.9545 - val_accuracy: 0.9977 - val_auc: 0.9997 - val_loss: 0.3169 - val_precision: 0.9987 - val_recall: 0.9967 - learning_rate: 1.0000e-04
# Epoch 2/20
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9932 - auc: 0.9992 - loss: 0.3076 - precision: 0.9945 - recall: 0.9921
# Epoch 2: val_auc improved from 0.99972 to 0.99986, saving model to models/best_model.keras
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 106s 105ms/step - accuracy: 0.9932 - auc: 0.9992 - loss: 0.3076 - precision: 0.9945 - recall: 0.9921 - val_accuracy: 0.9986 - val_auc: 0.9999 - val_loss: 0.2311 - val_precision: 0.9977 - val_recall: 0.9995 - learning_rate: 1.0000e-04
# Epoch 3/20
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9949 - auc: 0.9992 - loss: 0.2270 - precision: 0.9962 - recall: 0.9938
# Epoch 3: val_auc did not improve from 0.99986
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 104s 104ms/step - accuracy: 0.9949 - auc: 0.9992 - loss: 0.2270 - precision: 0.9962 - recall: 0.9938 - val_accuracy: 0.9989 - val_auc: 0.9997 - val_loss: 0.1725 - val_precision: 0.9982 - val_recall: 0.9995 - learning_rate: 1.0000e-04
# Epoch 4/20
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9942 - auc: 0.9991 - loss: 0.1753 - precision: 0.9946 - recall: 0.9940
# Epoch 4: val_auc did not improve from 0.99986
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 104s 104ms/step - accuracy: 0.9942 - auc: 0.9991 - loss: 0.1753 - precision: 0.9946 - recall: 0.9940 - val_accuracy: 0.9990 - val_auc: 0.9997 - val_loss: 0.1335 - val_precision: 0.9985 - val_recall: 0.9995 - learning_rate: 1.0000e-04
# Epoch 5/20
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9948 - auc: 0.9995 - loss: 0.1369 - precision: 0.9956 - recall: 0.9942
# Epoch 5: val_auc did not improve from 0.99986
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 104s 104ms/step - accuracy: 0.9948 - auc: 0.9995 - loss: 0.1369 - precision: 0.9956 - recall: 0.9942 - val_accuracy: 0.9986 - val_auc: 0.9997 - val_loss: 0.1062 - val_precision: 0.9977 - val_recall: 0.9995 - learning_rate: 1.0000e-04
# Epoch 6/20
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9953 - auc: 0.9993 - loss: 0.1121 - precision: 0.9960 - recall: 0.9947
# Epoch 6: val_auc did not improve from 0.99986
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 104s 104ms/step - accuracy: 0.9953 - auc: 0.9993 - loss: 0.1121 - precision: 0.9960 - recall: 0.9947 - val_accuracy: 0.9989 - val_auc: 0.9997 - val_loss: 0.0864 - val_precision: 0.9980 - val_recall: 0.9997 - learning_rate: 1.0000e-04
# Epoch 7/20
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9948 - auc: 0.9993 - loss: 0.0960 - precision: 0.9959 - recall: 0.9938
# Epoch 7: val_auc did not improve from 0.99986
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 104s 104ms/step - accuracy: 0.9948 - auc: 0.9993 - loss: 0.0960 - precision: 0.9959 - recall: 0.9938 - val_accuracy: 0.9989 - val_auc: 0.9997 - val_loss: 0.0719 - val_precision: 0.9985 - val_recall: 0.9992 - learning_rate: 1.0000e-04
# Epoch 7: early stopping
# Restoring model weights from the end of the best epoch: 2.
#
# ============================================================
# ✓ PHASE 1 COMPLETE
# ============================================================

# %% [markdown]
# #### this part of the code was generated using gpt, i got too bored to write it myself  lol

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import load_model
from sklearn.metrics import (
    confusion_matrix,
    classification_report
)
import os
import random

def load_best_model(model_path):
    print("=" * 60)
    print(f"🔍 Loading best model from: {model_path}")
    print("=" * 60)

    model = load_model(model_path)
    print("✓ Model loaded successfully!")
    return model

best_model = load_best_model('models/best_model.keras')

#load the saved model
def load_best_model(model_path='models/best_model.keras'):
    """
    Load the best model saved during training
    """
    print("=" * 60)
    print("Loading best model...")
    print("=" * 60)

    model = load_model(model_path)
    print(" Model loaded successfully!")

    return model

best_model = load_best_model('models/best_model.keras')

#evaluate the model on the validation data
def evaluate_model(model, validation_dataset):
    """
    Evaluate the model on validation data and print metrics
    """
    print("\n" + "=" * 60)
    print("EVALUATING MODEL ON VALIDATION SET")
    print("=" * 60)

    results = model.evaluate(validation_dataset, verbose=1)

    print("\n" + "=" * 60)
    print("VALIDATION RESULTS:")
    print("=" * 60)
    print(f"Loss: {results[0]:.4f}")
    print(f"Accuracy: {results[1]:.4f} ({results[1]*100:.2f}%)")
    print(f"Precision: {results[2]:.4f}")
    print(f"Recall: {results[3]:.4f}")
    print(f"AUC: {results[4]:.4f}")
    print("=" * 60)

    return results

# Evaluate the model
evaluation_results = evaluate_model(best_model, validation_dataset)


# ============================================================
# 3. GET PREDICTIONS AND TRUE LABELS
# ============================================================

def get_predictions_and_labels(model, dataset):
    """
    Get predictions and true labels from the dataset
    """
    print("\n" + "=" * 60)
    print("GENERATING PREDICTIONS...")
    print("=" * 60)

    y_true = []
    y_pred_probs = []

    # Get predictions for all batches
    for images, labels in dataset:
        predictions = model.predict(images, verbose=0)
        y_pred_probs.extend(predictions.flatten())
        y_true.extend(labels.numpy().flatten())

    y_true = np.array(y_true)
    y_pred_probs = np.array(y_pred_probs)
    y_pred = (y_pred_probs > 0.5).astype(int)  # Convert probabilities to binary predictions

    print(f"✓ Generated {len(y_true)} predictions")

    return y_true, y_pred, y_pred_probs

# Get predictions
y_true, y_pred, y_pred_probs = get_predictions_and_labels(best_model, validation_dataset)


# ============================================================
# 4. CONFUSION MATRIX
# ============================================================

def plot_confusion_matrix(y_true, y_pred):
    """
    Plot confusion matrix to visualize model performance
    """
    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=True,
                xticklabels=['No Crack (0)', 'Crack (1)'],
                yticklabels=['No Crack (0)', 'Crack (1)'])

    plt.title('Confusion Matrix', fontsize=16, fontweight='bold', pad=20)
    plt.ylabel('True Label', fontsize=12, fontweight='bold')
    plt.xlabel('Predicted Label', fontsize=12, fontweight='bold')

    # Add text annotations for better understanding
    total = cm.sum()
    accuracy = (cm[0,0] + cm[1,1]) / total

    plt.text(1, -0.3, f'Overall Accuracy: {accuracy:.4f} ({accuracy*100:.2f}%)',
             ha='center', fontsize=12, fontweight='bold',
             transform=plt.gca().transAxes)

    plt.tight_layout()
    plt.show()

    # Print confusion matrix statistics
    print("\n" + "=" * 60)
    print("CONFUSION MATRIX BREAKDOWN:")
    print("=" * 60)
    print(f"True Negatives (Correct No Crack): {cm[0,0]}")
    print(f"False Positives (Wrongly predicted Crack): {cm[0,1]}")
    print(f"False Negatives (Missed Cracks): {cm[1,0]}")
    print(f"True Positives (Correct Crack detection): {cm[1,1]}")
    print("=" * 60)

    return cm

# Plot confusion matrix
cm = plot_confusion_matrix(y_true, y_pred)


# ============================================================
# 5. CLASSIFICATION REPORT
# ============================================================

def print_classification_report(y_true, y_pred):
    """
    Print detailed classification report
    """
    print("\n" + "=" * 60)
    print("DETAILED CLASSIFICATION REPORT")
    print("=" * 60)

    report = classification_report(y_true, y_pred,
                                    target_names=['No Crack', 'Crack'],
                                    digits=4)
    print(report)

    print("\nMetrics Explanation:")
    print("  - Precision: Of all crack predictions, how many were correct?")
    print("  - Recall: Of all actual cracks, how many did we detect?")
    print("  - F1-Score: Harmonic mean of precision and recall")
    print("  - Support: Number of samples in each class")
    print("=" * 60)

# Print classification report
print_classification_report(y_true, y_pred)


# ============================================================
# 6. PREDICTION DISTRIBUTION
# ============================================================

def plot_prediction_distribution(y_true, y_pred_probs):
    """
    Visualize the distribution of prediction probabilities
    """
    plt.figure(figsize=(14, 6))

    # Separate probabilities by true class
    no_crack_probs = y_pred_probs[y_true == 0]
    crack_probs = y_pred_probs[y_true == 1]

    # Plot 1: Histogram
    plt.subplot(1, 2, 1)
    plt.hist(no_crack_probs, bins=50, alpha=0.7, label='No Crack (True)', color='blue', edgecolor='black')
    plt.hist(crack_probs, bins=50, alpha=0.7, label='Crack (True)', color='red', edgecolor='black')
    plt.axvline(x=0.5, color='green', linestyle='--', linewidth=2, label='Decision Threshold (0.5)')
    plt.xlabel('Predicted Probability', fontsize=12, fontweight='bold')
    plt.ylabel('Frequency', fontsize=12, fontweight='bold')
    plt.title('Distribution of Prediction Probabilities', fontsize=14, fontweight='bold')
    plt.legend()
    plt.grid(True, alpha=0.3)

    # Plot 2: Box plot
    plt.subplot(1, 2, 2)
    data_to_plot = [no_crack_probs, crack_probs]
    box = plt.boxplot(data_to_plot, labels=['No Crack (True)', 'Crack (True)'],
                      patch_artist=True, showmeans=True)

    # Color the boxes
    colors = ['blue', 'red']
    for patch, color in zip(box['boxes'], colors):
        patch.set_facecolor(color)
        patch.set_alpha(0.6)

    plt.axhline(y=0.5, color='green', linestyle='--', linewidth=2, label='Threshold (0.5)')
    plt.ylabel('Predicted Probability', fontsize=12, fontweight='bold')
    plt.title('Prediction Probability Box Plot', fontsize=14, fontweight='bold')
    plt.legend()
    plt.grid(True, alpha=0.3, axis='y')

    plt.tight_layout()
    plt.show()

    print("\n" + "=" * 60)
    print("PREDICTION CONFIDENCE STATISTICS")
    print("=" * 60)
    print(f"No Crack samples - Mean confidence: {no_crack_probs.mean():.4f}")
    print(f"Crack samples - Mean confidence: {crack_probs.mean():.4f}")
    print("=" * 60)

# Plot prediction distribution
plot_prediction_distribution(y_true, y_pred_probs)


# ============================================================
# 7. VISUALIZE SAMPLE PREDICTIONS
# ============================================================

def visualize_predictions(model, dataset, n_samples=10):
    """
    Visualize sample predictions with their actual labels
    """
    # Get one batch of images and labels
    for images, labels in dataset.take(1):
        predictions = model.predict(images, verbose=0)

        # Select random samples
        indices = np.random.choice(len(images), min(n_samples, len(images)), replace=False)

        # Create subplots
        fig, axes = plt.subplots(2, 5, figsize=(20, 8))
        fig.suptitle('Sample Predictions vs Actual Labels', fontsize=16, fontweight='bold')

        for idx, ax in enumerate(axes.flat):
            if idx < len(indices):
                i = indices[idx]
                img = images[i].numpy()
                true_label = int(labels[i].numpy())
                pred_prob = predictions[i][0]
                pred_label = int(pred_prob > 0.5)

                # Denormalize image for display (EfficientNet preprocessing uses [-1, 1])
                img_display = (img - img.min()) / (img.max() - img.min())

                ax.imshow(img_display)
                ax.axis('off')

                # Color code: green for correct, red for incorrect
                color = 'green' if pred_label == true_label else 'red'

                title = f"True: {'Crack' if true_label else 'No Crack'}\n"
                title += f"Pred: {'Crack' if pred_label else 'No Crack'}\n"
                title += f"Confidence: {pred_prob:.3f}" if pred_label else f"Confidence: {1-pred_prob:.3f}"

                ax.set_title(title, color=color, fontweight='bold', fontsize=10)
            else:
                ax.axis('off')

        plt.tight_layout()
        plt.show()
        break

# Visualize sample predictions
visualize_predictions(best_model, validation_dataset, n_samples=10)


# ============================================================
# 8. ERROR ANALYSIS - FIND MISCLASSIFIED IMAGES
# ============================================================

def analyze_errors(model, dataset, max_errors=10):
    """
    Find and visualize misclassified images to understand model failures
    """
    print("\n" + "=" * 60)
    print("ANALYZING MISCLASSIFIED IMAGES")
    print("=" * 60)

    misclassified_images = []
    misclassified_labels = []
    misclassified_preds = []
    misclassified_probs = []

    # Collect misclassified samples
    for images, labels in dataset:
        predictions = model.predict(images, verbose=0)
        pred_labels = (predictions > 0.5).astype(int).flatten()
        true_labels = labels.numpy().flatten()

        # Find misclassified indices in this batch
        misclassified_idx = np.where(pred_labels != true_labels)[0]

        for idx in misclassified_idx:
            if len(misclassified_images) < max_errors:
                misclassified_images.append(images[idx].numpy())
                misclassified_labels.append(true_labels[idx])
                misclassified_preds.append(pred_labels[idx])
                misclassified_probs.append(predictions[idx][0])

        if len(misclassified_images) >= max_errors:
            break

    if len(misclassified_images) == 0:
        print("✓ NO MISCLASSIFIED IMAGES FOUND! Perfect predictions!")
        print("=" * 60)
        return

    print(f"Found {len(misclassified_images)} misclassified images")
    print("=" * 60)

    # Visualize misclassified images
    n_rows = (len(misclassified_images) + 4) // 5
    fig, axes = plt.subplots(n_rows, 5, figsize=(20, 4*n_rows))
    fig.suptitle('Misclassified Images - Understanding Model Errors',
                 fontsize=16, fontweight='bold', color='red')

    if n_rows == 1:
        axes = axes.reshape(1, -1)

    for idx, ax in enumerate(axes.flat):
        if idx < len(misclassified_images):
            img = misclassified_images[idx]
            true_label = misclassified_labels[idx]
            pred_label = misclassified_preds[idx]
            pred_prob = misclassified_probs[idx]

            # Denormalize for display
            img_display = (img - img.min()) / (img.max() - img.min())

            ax.imshow(img_display)
            ax.axis('off')

            title = f"True: {'Crack' if true_label else 'No Crack'}\n"
            title += f"Predicted: {'Crack' if pred_label else 'No Crack'}\n"
            title += f"Confidence: {pred_prob:.3f}" if pred_label else f"Confidence: {1-pred_prob:.3f}"

            ax.set_title(title, color='red', fontweight='bold', fontsize=10)
        else:
            ax.axis('off')

    plt.tight_layout()
    plt.show()

# Analyze errors
analyze_errors(best_model, validation_dataset, max_errors=10)


# ============================================================
# 9. SAVE EVALUATION SUMMARY
# ============================================================

def save_evaluation_summary(results, cm, y_true, y_pred):
    """
    Save evaluation metrics to a text file
    """
    with open('models/evaluation_summary.txt', 'w') as f:
        f.write("=" * 60 + "\n")
        f.write("CONCRETE CRACK DETECTION - EVALUATION SUMMARY\n")
        f.write("=" * 60 + "\n\n")

        f.write("MODEL PERFORMANCE METRICS:\n")
        f.write("-" * 60 + "\n")
        f.write(f"Loss: {results[0]:.4f}\n")
        f.write(f"Accuracy: {results[1]:.4f} ({results[1]*100:.2f}%)\n")
        f.write(f"Precision: {results[2]:.4f}\n")
        f.write(f"Recall: {results[3]:.4f}\n")
        f.write(f"AUC: {results[4]:.4f}\n\n")

        f.write("CONFUSION MATRIX:\n")
        f.write("-" * 60 + "\n")
        f.write(f"True Negatives: {cm[0,0]}\n")
        f.write(f"False Positives: {cm[0,1]}\n")
        f.write(f"False Negatives: {cm[1,0]}\n")
        f.write(f"True Positives: {cm[1,1]}\n\n")

        f.write("CLASSIFICATION REPORT:\n")
        f.write("-" * 60 + "\n")
        f.write(classification_report(y_true, y_pred,
                                      target_names=['No Crack', 'Crack'],
                                      digits=4))

        f.write("\n" + "=" * 60 + "\n")

    print("\n✓ Evaluation summary saved to 'models/evaluation_summary.txt'")

# Save evaluation summary
save_evaluation_summary(evaluation_results, cm, y_true, y_pred)
# Out:
# ============================================================
# 🔍 Loading best model from: models/best_model.keras
# ============================================================
# ✓ Model loaded successfully!
# ============================================================
# Loading best model...
# ============================================================
# ✓ Model loaded successfully!
#
# ============================================================
# EVALUATING MODEL ON VALIDATION SET
# ============================================================
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 76ms/step - accuracy: 0.9986 - auc: 0.9998 - loss: 0.2313 - precision: 0.9980 - recall: 0.9992
#
# ============================================================
# VALIDATION RESULTS:
# ============================================================
# Loss: 0.2311
# Accuracy: 0.9986 (99.86%)
# Precision: 0.9977
# Recall: 0.9995
# AUC: 0.9999
# ============================================================
#
# ============================================================
# GENERATING PREDICTIONS...
# ============================================================
# ✓ Generated 8000 predictions
# ============================================================
# CONFUSION MATRIX BREAKDOWN:
# ============================================================
# True Negatives (Correct No Crack): 4071
# False Positives (Wrongly predicted Crack): 9
# False Negatives (Missed Cracks): 2
# True Positives (Correct Crack detection): 3918
# ============================================================
#
# ============================================================
# DETAILED CLASSIFICATION REPORT
# ============================================================
#               precision    recall  f1-score   support
#
#     No Crack     0.9995    0.9978    0.9987      4080
#        Crack     0.9977    0.9995    0.9986      3920
#
#     accuracy                         0.9986      8000
#    macro avg     0.9986    0.9986    0.9986      8000
# weighted avg     0.9986    0.9986    0.9986      8000
#
#
# Metrics Explanation:
#   - Precision: Of all crack predictions, how many were correct?
#   - Recall: Of all actual cracks, how many did we detect?
#   - F1-Score: Harmonic mean of precision and recall
#   - Support: Number of samples in each class
# ============================================================
# /tmp/ipython-input-3031607087.py:202: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   box = plt.boxplot(data_to_plot, labels=['No Crack (True)', 'Crack (True)'],
# ============================================================
# PREDICTION CONFIDENCE STATISTICS
# ============================================================
# No Crack samples - Mean confidence: 0.0028
# Crack samples - Mean confidence: 0.9978
# ============================================================
# /tmp/ipython-input-3031607087.py:254: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   true_label = int(labels[i].numpy())
# ============================================================
# ANALYZING MISCLASSIFIED IMAGES
# ============================================================
# Found 10 misclassified images
# ============================================================
# ✓ Evaluation summary saved to 'models/evaluation_summary.txt'

# %%
from google.colab import files

# The path where ModelCheckpoint saved your best model
model_path = 'models/best_model.keras'

# Download to local
files.download(model_path)

# %%
# # ============================================================
# # STEP 1: Create project folder and copy important files
# # ============================================================

# !mkdir -p safequak_project_v1.0/models

# # Copy your model and evaluation summary
# !cp -r models/best_model.keras safequak_project_v1.0/models/
# !cp -r models/evaluation_summary.txt safequak_project_v1.0/models/

# # Copy your final notebook
# !cp -r code.ipynb safequak_project_v1.0/

# # ============================================================
# # STEP 2: Zip the entire project folder
# # ============================================================

# !zip -r safequak_project_v1.0_new.zip safequak_project_v1.0

# # ============================================================
# # STEP 3: Download the zip file (for Google Colab)
# # ============================================================

# from google.colab import files
# files.download('safequak_project_v1.0_new.zip')
