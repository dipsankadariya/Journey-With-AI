# %%
from keras import Sequential
from keras.layers import Dense,SimpleRNN

# %%
model=Sequential()
model.add(SimpleRNN(3,input_shape=(4,5)))
model.add(Dense(1,activation="sigmoid"))
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_1 (SimpleRNN)        │ (None, 3)              │            27 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             4 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31 (124.00 B)
#  Trainable params: 31 (124.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
print(model.get_weights()[0])
# Out:
# [[-0.6043114  -0.75911474  0.4600789 ]
#  [-0.29391629  0.20942539 -0.09840238]
#  [ 0.04455352  0.28560656 -0.3502288 ]
#  [ 0.10652518 -0.6673155  -0.35963488]
#  [-0.6595379  -0.09238321  0.6606031 ]]

# %%
print(model.get_weights()[0].shape)
# Out:
# (5, 3)

# %%
print(model.get_weights()[1])
# Out:
# [[-0.12073648 -0.89175546  0.43611333]
#  [ 0.17125091 -0.45145148 -0.8757081 ]
#  [-0.9778015   0.03104514 -0.20722064]]

# %%
print(model.get_weights()[1].shape)
# Out:
# (3, 3)

# %%
print(model.get_weights()[2])
# Out:
# [0. 0. 0.]

# %%
print(model.get_weights()[2].shape)
# Out:
# (3,)

# %%
print(model.get_weights()[3])
# Out:
# [[-0.5787058 ]
#  [-0.37271798]
#  [-0.92462736]]

# %%
print(model.get_weights()[3].shape)
# Out:
# (3, 1)

# %%
print(model.get_weights()[4])
# Out:
# [0.]

# %%
print(model.get_weights()[4].shape)
# Out:
# (1,)

# %% [markdown]
# #### Forward prop in RNN
